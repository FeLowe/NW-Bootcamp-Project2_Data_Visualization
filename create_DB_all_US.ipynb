# %%
import requests
import json
from pprint import pprint
import numpy as np
import pandas as pd
import os
import csv
import datetime as dt

from sqlalchemy import MetaData
from sqlalchemy import Table
from sqlalchemy import Column
from sqlalchemy import Integer, String, Float

import sqlalchemy
from sqlalchemy import create_engine, func, inspect
from sqlalchemy_utils import database_exists, create_database
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float, Date, Double

from math import radians, sin, cos, asin, sqrt # used to calculate distance of room and city longs and lats

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

import multiprocessing as mp

# Google API Key
# from config import gkey
from flask import Flask, jsonify
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-115-2b8e25560248> in <module>
#      17 from sqlalchemy_utils import database_exists, create_database
#      18 from sqlalchemy.ext.declarative import declarative_base
# ---> 19 from sqlalchemy import Column, Integer, String, Numeric, Text, Float, Date, Double
#      20
#      21 from math import radians, sin, cos, asin, sqrt # used to calculate distance of room and city longs and lats
#
# ImportError: cannot import name 'Double'

# %%
countryList = ["United States"]

# %%
# results = requests.get(f'https://public.opendatasoft.com/api/records/1.0/download/?dataset=air-bnb-listings&facet=city&facet={x}&facet=geolocation&facet=id&facet=geolocation&facet=name&facet=price&facet=room_type&format=json').json()
def api_call(x):
    results = requests.get(f'https://data.opendatasoft.com/api/records/1.0/download/?dataset=airbnb-listings%40public&facet=city&facet=country&facet=geolocation&facet=id&facet=geolocation&facet=name&facet=price&facet=room_type&refine.country={x}&format=json').json()
    results = [r["fields"] for r in results]
    return results

# %%
def main():
  pool = mp.Pool(9)
  result = pool.map(api_call, countryList)
  return result

if __name__ == "__main__":
    result = main()

# %%
pprint(result[0][0])
# Out:
# {'access': "We're in the heart of the Mission. Located on a small, quiet "
#            'street between Valencia and Mission Streets, we are surrounded by '
#            'all the awesome bars, restaurants and shopping of the Mission. '
#            'Craft beer bars The Best Tacos and Burritos Dolores Park '
#            'Michelin-starred restaurants Tartine Bakery Hipster fashion '
#            'Artisinal chocolate factories GREAT coffee  Incredible murals  '
#            'Sunshine (The Mission gets more sun that the rest of San '
#            'Francisco) These are just some of the things available within a '
#            'one minute walk from our pad. As foodies we have a list of amazing '
#            "bars and restaurants you should check out while you're here. And "
#            "don't hesitate to ask if there's something in particular you're "
#            'looking for. Getting Around The BART (aka subway, train, tube, '
# ...

# %%
# results = [r["fields"] for r in result[0]]
#results

# %%
results_df = pd.DataFrame(result[0])
results_df.head()
# Out:
#                                               access  accommodates  \
# 0  We're in the heart of the Mission. Located on ...           2.0
# 1                                                NaN           3.0
# 2  Guests will have shared access to all the comm...           4.0
# 3  Shared access through the front door.  You are...           2.0
# 4  If possible. we will meet you and give you key...           2.0
#
#                                            amenities  availability_30  \
# 0  TV,Wireless Internet,Kitchen,Buzzer/wireless i...                0
# 1  TV,Cable TV,Wireless Internet,Kitchen,Elevator...               30
# 2  TV,Internet,Wireless Internet,Kitchen,Free par...               13
# 3  TV,Internet,Wireless Internet,Heating,Family/k...               30
# 4  TV,Cable TV,Internet,Wireless Internet,Air con...                1
#
#    availability_365  availability_60  availability_90  bathrooms  bed_type  \
# ...

# %%
columns = results_df.columns.tolist()
columns
# Out:
# ['access',
#  'accommodates',
#  'amenities',
#  'availability_30',
#  'availability_365',
#  'availability_60',
#  'availability_90',
#  'bathrooms',
#  'bed_type',
#  'bedrooms',
#  'beds',
#  'calculated_host_listings_count',
#  'calendar_last_scraped',
#  'calendar_updated',
#  'cancellation_policy',
#  'city',
#  'cleaning_fee',
#  'country',
#  'country_code',
#  'description',
#  'experiences_offered',
#  'extra_people',
#  'features',
#  'first_review',
#  'geolocation',
#  'guests_included',
#  'has_availability',
#  'host_about',
#  'host_acceptance_rate',
#  'host_id',
#  'host_listings_count',
#  'host_location',
#  'host_name',
#  'host_neighbourhood',
#  'host_picture_url',
#  'host_response_rate',
#  'host_response_time',
#  'host_since',
#  'host_thumbnail_url',
#  'host_total_listings_count',
#  'host_url',
#  'host_verifications',
#  'house_rules',
#  'id',
#  'interaction',
#  'jurisdiction_names',
#  'last_review',
#  'last_scraped',
#  'latitude',
#  'license',
# ...

# %%
cleanData = results_df[[ 'price','id', 'geolocation', 'room_type', "city", 'country']]
cleanData.head()
# Out:
#    price        id                               geolocation        room_type  \
# 0  125.0  11067041  [37.76221382842841, -122.42032216865074]     Private room
# 1    NaN   5859735  [37.79561314356756, -122.43301209465291]  Entire home/apt
# 2  100.0   8048653   [37.7129876927169, -122.40016991761325]     Private room
# 3  129.0   3310076  [37.78270446257035, -122.45475592448159]     Private room
# 4  130.0  10923918   [38.89277378649149, -76.99767929786395]  Entire home/apt
#
#             city        country
# 0  San Francisco  United States
# 1  San Francisco  United States
# 2  San Francisco  United States
# 3  San Francisco  United States
# 4     Washington  United States

# %%
cleanData = cleanData.rename(index=str, columns={"price":"Price",
                                                 "id":"Room_Id", 
                                                 "geolocation":"Coordinates",
                                                 "country":"Country", 
                                                 "room_type":"Room_Type",
                                                 "city":"City"})

cleanData.head()
# Out:
#    Price   Room_Id                               Coordinates        Room_Type  \
# 0  125.0  11067041  [37.76221382842841, -122.42032216865074]     Private room
# 1    NaN   5859735  [37.79561314356756, -122.43301209465291]  Entire home/apt
# 2  100.0   8048653   [37.7129876927169, -122.40016991761325]     Private room
# 3  129.0   3310076  [37.78270446257035, -122.45475592448159]     Private room
# 4  130.0  10923918   [38.89277378649149, -76.99767929786395]  Entire home/apt
#
#             City        Country
# 0  San Francisco  United States
# 1  San Francisco  United States
# 2  San Francisco  United States
# 3  San Francisco  United States
# 4     Washington  United States

# %%
# Create two lists for the loop results to be placed
lat = []
lon = []

# For each row in a varible,
for row in cleanData['Coordinates']:
   # Try to,
   try:
       # Split the row by comma and append
       # everything before the comma to lat
       lat.append(row[0])
       # Split the row by comma and append
       # everything after the comma to lon
       lon.append(row[1])
   # But if you get an error
   except:
       # append a missing value to lat
       lat.append(np.NaN)
       # append a missing value to lon
       lon.append(np.NaN)

# Create two new columns from lat and lon
cleanData['Room_Lat'] = lat
cleanData['Room_Long'] = lon

# %%
# cleanData = cleanData.drop(columns=["Coordinates"])
# cleanData.head()

# %%
cleanData["Selection"] = cleanData["City"]+", "+cleanData["Country"]
cleanData.head(5)
# Out:
#    Price   Room_Id                               Coordinates        Room_Type  \
# 0  125.0  11067041  [37.76221382842841, -122.42032216865074]     Private room
# 1    NaN   5859735  [37.79561314356756, -122.43301209465291]  Entire home/apt
# 2  100.0   8048653   [37.7129876927169, -122.40016991761325]     Private room
# 3  129.0   3310076  [37.78270446257035, -122.45475592448159]     Private room
# 4  130.0  10923918   [38.89277378649149, -76.99767929786395]  Entire home/apt
#
#             City        Country   Room_Lat   Room_Long  \
# 0  San Francisco  United States  37.762214 -122.420322
# 1  San Francisco  United States  37.795613 -122.433012
# 2  San Francisco  United States  37.712988 -122.400170
# 3  San Francisco  United States  37.782704 -122.454756
# 4     Washington  United States  38.892774  -76.997679
#
#                       Selection
# 0  San Francisco, United States
# 1  San Francisco, United States
# 2  San Francisco, United States
# ...

# %%
cleanData['City'] = cleanData['City'].str.replace('-',' ')
# cleanData

# %%
cities = []

for index, row in cleanData.iterrows():
    if row["Selection"] not in cities:
        cities.append(row["Selection"])

cities_df = pd.DataFrame(cities)
cities_df
# Out:
#                                                      0
# 0                         San Francisco, United States
# 1                            Washington, United States
# 2             Dupont Circle, Washington, United States
# 3                            Santa Cruz, United States
# 4                               Seattle, United States
# 5                                Soquel, United States
# 6                           Rio Del Mar, United States
# 7                              Bethesda, United States
# 8                           Hyattsville, United States
# 9                              Brooklyn, United States
# 10                        Mount Rainier, United States
# 11                     Washington, D.C., United States
# 12   Washington, District of Columbia, US, United S...
# 13                        Silver Spring, United States
# 14                          Watsonville, United States
# 15                        Boulder Creek, United States
# ...

# %%
city_lats = []
city_lons =[]

for index, row in cities_df.iterrows():
    
#     pprint(row[0])
    
    gkey = "AIzaSyAL_3t-K2F-8_HQde0JpXON-x_X70Nn5Mw"
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(row[0], gkey)
    
    try:
    
        cities_lat_long = requests.get(target_url).json()
        city_lat = cities_lat_long["results"][0]["geometry"]["location"]["lat"]
        city_long = cities_lat_long["results"][0]["geometry"]["location"]["lng"]

        city_lats.append(city_lat)
        city_lons.append(city_long)
    
    except:
        city_lats.append("")
        city_lons.append("")

# %%
city_lats
# Out:
# [37.7749295,
#  47.7510741,
#  38.9096936,
#  36.9741171,
#  47.6062095,
#  36.9880057,
#  36.9597903,
#  38.984652,
#  38.9559442,
#  40.6781784,
#  38.9415,
#  38.9071923,
#  38.9071923,
#  38.99066570000001,
#  36.910231,
#  37.12605780000001,
#  37.2358078,
#  37.0891143,
#  38.8851122,
#  36.97717290000001,
#  37.7749295,
#  37.0513374,
#  37.0416156,
#  41.5236437,
#  36.9752283,
#  38.8140024,
#  37.8715926,
#  36.9637177,
#  37.0510595,
#  37.7389496,
#  47.5666668,
#  38.9097057,
#  37.7598648,
#  47.6062095,
#  37.7749295,
#  36.988562,
#  47.6062095,
#  37.0494418,
#  36.9597903,
#  33.8622366,
#  34.0522342,
#  34.0928092,
#  34.0928092,
#  34.055103,
#  33.9930677,
#  33.9164032,
#  34.1425078,
#  38.4783198,
#  34.1361187,
#  34.0211224,
#  34.2068182,
#  33.9616801,
#  34.228754,
#  34.1008426,
#  33.887237,
#  33.9761238,
#  33.9816812,
#  33.9802893,
#  33.8536269,
#  33.9172357,
#  40.0378755,
#  34.0200114,
#  34.0152567,
#  33.9850469,
#  33.7700504,
# ...

# %%
cities_df['lat'] = city_lats
cities_df['lon'] = city_lons

cities_df.columns = ["Selection", "Center Lat", "Center Lon"]

cleanData = cleanData.merge(cities_df, left_on='Selection', right_on='Selection')

# %%
cleanData = cleanData[cleanData['Center Lat'] != '']
cleanData = cleanData[cleanData['Center Lon'] != '']

# %%
calculated_distance = []

for index, row in cleanData.iterrows():
    room_lat1 = row['Room_Lat']
    room_long1 = row['Room_Long']
    city_lat2 = row['Center Lat']
    city_long2 = row['Center Lon']
    
#CALCULATES DISTANCE OF ROOMS AND CITIES LAT AND LONGS
    def distance(room_long1, room_lat1, city_long2, city_lat2):
        room_long1, room_lat1, city_long2, city_lat2 = map(radians, [room_long1, room_lat1, city_long2, city_lat2])
        dlon = city_long2 - room_long1
        dlat = city_lat2 - room_lat1
        a = sin(dlat / 2) ** 2 + cos(room_lat1) * cos(city_lat2) * sin(dlon / 2) ** 2
        return 2 * 3958.756 * asin(sqrt(a)) #6371 km / 3958.756 for miles

    room_city_distance = distance(room_long1, room_lat1, city_long2, city_lat2)

    
    calculated_distance.append(room_city_distance)
    
print("calculated_distance:", calculated_distance)
# Out:
# calculated_distance: [0.8799625310172787, 1.610452877360763, 4.407044528443277, 2.0033134370522356, 1.7489677598936937, 1.3596763254437556, 1.6906184142445135, 1.9580304941531546, 1.31207704064537, 1.8193415758107725, 0.2755407951579022, 1.7008148552088822, 2.260630850623474, 1.1832263666423686, 1.3053668911118148, 1.062812136703091, 2.4307552853370695, 1.2534011228851494, 4.371846664559889, 0.9001990966764766, 1.9188796536715957, 0.20870272975692236, 0.7273475590694124, 3.5057977608098363, 4.00221807041192, 1.336434760938146, 0.5544391535701141, 3.189134908791314, 4.482619831242976, 1.7996663150806271, 1.1793869340953758, 1.9476271291484228, 2.596434375678556, 2.876606481235957, 1.8157287059320275, 1.1024215193953304, 1.1928762660218033, 2.194087062227079, 1.1577153914883678, 1.4149450632545513, 1.5146530605764004, 2.037864171016143, 1.34837753569584, 1.2011886966094274, 1.9414190438308572, 3.453740253163072, 0.9485623417720732, 5.320814401579684, 1.140332912560278, 3.78752615006336
# ...

# %%
cleanData['Calc_Distance'] = calculated_distance

# %%
cleanData.head()
# Out:
#    Price   Room_Id                               Coordinates        Room_Type  \
# 0  125.0  11067041  [37.76221382842841, -122.42032216865074]     Private room
# 1    NaN   5859735  [37.79561314356756, -122.43301209465291]  Entire home/apt
# 2  100.0   8048653   [37.7129876927169, -122.40016991761325]     Private room
# 3  129.0   3310076  [37.78270446257035, -122.45475592448159]     Private room
# 4  130.0    681521  [37.79972166268961, -122.42588032265553]     Private room
#
#             City        Country   Room_Lat   Room_Long  \
# 0  San Francisco  United States  37.762214 -122.420322
# 1  San Francisco  United States  37.795613 -122.433012
# 2  San Francisco  United States  37.712988 -122.400170
# 3  San Francisco  United States  37.782704 -122.454756
# 4  San Francisco  United States  37.799722 -122.425880
#
#                       Selection Center Lat Center Lon  Calc_Distance
# 0  San Francisco, United States    37.7749   -122.419       0.879963
# ...

# %%
cleanData= cleanData.drop(columns=["Coordinates","Center Lat", "Center Lon"])
cleanData.head()
# Out:
#    Price   Room_Id        Room_Type           City        Country   Room_Lat  \
# 0  125.0  11067041     Private room  San Francisco  United States  37.762214
# 1    NaN   5859735  Entire home/apt  San Francisco  United States  37.795613
# 2  100.0   8048653     Private room  San Francisco  United States  37.712988
# 3  129.0   3310076     Private room  San Francisco  United States  37.782704
# 4  130.0    681521     Private room  San Francisco  United States  37.799722
#
#     Room_Long                     Selection  Calc_Distance
# 0 -122.420322  San Francisco, United States       0.879963
# 1 -122.433012  San Francisco, United States       1.610453
# 2 -122.400170  San Francisco, United States       4.407045
# 3 -122.454756  San Francisco, United States       2.003313
# 4 -122.425880  San Francisco, United States       1.748968

# %%
# #Export city names to csv
# cleanData.to_csv('../data.csv', index=False)

# # Import cities file as DataFrame
# cleanData_df = pd.read_csv("../data.csv")
# cleanData_df.head()

# %%
# this site confirmed the calculation is correct:
# https://www.gpsvisualizer.com/calculators

# %%
cleanData = cleanData.rename(index=str, columns={"Room_Lat":"Latitude",
                                                 "Room_Long":"Longitude", 
                                                 "Calc_Distance":"Distance"})

cleanData.head()
# Out:
#    Price   Room_Id        Room_Type           City        Country   Latitude  \
# 0  125.0  11067041     Private room  San Francisco  United States  37.762214
# 1    NaN   5859735  Entire home/apt  San Francisco  United States  37.795613
# 2  100.0   8048653     Private room  San Francisco  United States  37.712988
# 3  129.0   3310076     Private room  San Francisco  United States  37.782704
# 4  130.0    681521     Private room  San Francisco  United States  37.799722
#
#     Longitude                     Selection  Distance
# 0 -122.420322  San Francisco, United States  0.879963
# 1 -122.433012  San Francisco, United States  1.610453
# 2 -122.400170  San Francisco, United States  4.407045
# 3 -122.454756  San Francisco, United States  2.003313
# 4 -122.425880  San Francisco, United States  1.748968

# %%
conn_str = "root:helpme01@localhost/airbnb_data?charset=utf8"
engine = create_engine(f'mysql://{conn_str}')

if not database_exists(engine.url):
    create_database(engine.url)

# %%
engine.table_names()
# Out:
# []

# %%
metadata = MetaData(engine)

listings = Table('listings', metadata,
                 Column('Price', Integer),
                 Column('Room_Id', String(10)),
                 Column('Room_Type', String(25)),
                 Column('City', String(50)),
                 Column('Country', String(50)),
                 Column('Latitude', Float),
                 Column('Longitude', Float),
                 Column('Selection', String(100)),
                 Column('Distance', Float))

metadata.create_all()
for _t in metadata.tables:
    print("Table: ",_t)
# Out:
# Table:  listings

# %%
cleanData.to_sql(name="listings", con=engine, if_exists="append",index=False)

# %%
# selection = cleanData["Selection"]
selection1 = pd.DataFrame(cleanData.drop_duplicates(["Selection"]))
selection1 = selection1["Selection"]
selection1.head()
# Out:
# 0                    San Francisco, United States
# 8679                    Washington, United States
# 16371    Dupont Circle, Washington, United States
# 16374                   Santa Cruz, United States
# 16825                      Seattle, United States
# Name: Selection, dtype: object

# %%
listings_total_count = cleanData.shape[0]

grouped_listings = cleanData.groupby(['Selection'])
grouped_listings.count().head()

listings_per_city = grouped_listings['Selection'].value_counts()
# print(listings_count_per_city)

listings_perc_per_city = listings_per_city / listings_total_count*100
# print(listings_perc_per_city)

listings_total_price = grouped_listings['Price'].sum()
#print(listings_total_price)

listings_avg_price = listings_total_price / listings_per_city
# print(listings_avg_price)

selection2 = pd.DataFrame({"Number_of_Listings": listings_per_city, 
                            "Perc_of_Listings": listings_perc_per_city,
                            "Avg_Price": listings_avg_price})

selection2["Perc_of_Listings"] = selection2["Perc_of_Listings"].map("{:.0f}".format)

selection2.reset_index(drop=True, inplace=True)

selection2.head()
# Out:
#    Number_of_Listings Perc_of_Listings  Avg_Price
# 0                   1                0     105.00
# 1                   1                0      52.00
# 2                   2                0     165.00
# 3                   1                0      80.00
# 4                   4                0      83.75

# %%
# min_price= cleanData.groupby('Selection')['Price'].transform('min')
# max_price = cleanData.groupby('Selection')['Price'].transform('max')
                                      
# selection3 = pd.DataFrame({"Max_Price": max_price.drop_duplicates(),
#                             "Min_Price": min_price.drop_duplicates()})

# selection_1_3 = pd.concat([selection1, selection3,], axis=1)
# selection_1_3


selection_df = cities_df.merge(selection2,left_index=True, right_index=True)
selection_df
# Out:
#                                              Selection Center Lat Center Lon  \
# 0                         San Francisco, United States    37.7749   -122.419
# 1                            Washington, United States    47.7511    -120.74
# 2             Dupont Circle, Washington, United States    38.9097   -77.0433
# 3                            Santa Cruz, United States    36.9741   -122.031
# 4                               Seattle, United States    47.6062   -122.332
# 5                                Soquel, United States     36.988   -121.957
# 6                           Rio Del Mar, United States    36.9598   -121.885
# 7                              Bethesda, United States    38.9847   -77.0947
# 8                           Hyattsville, United States    38.9559   -76.9455
# 9                              Brooklyn, United States    40.6782   -73.9442
# 10                        Mount Rainier, United States    38.9415    -76.965
# ...

# %%
# selection_df = selection2.merge(pd.DataFrame(data = [selection1.values] * len(selection1), columns = selection1.index), left_index=True, right_index=True)
# selection_df = selection_df.rename(index=str, columns={"0":"Selection"}) 
# selection_df

selection_df = selection_df.drop(["Center Lat", "Center Lon"], axis=1)

# %%
cities = Table('cities', metadata,
                 Column('Selection', String(100)),
                 Column('Number_of_Listings', Float),
                 Column('Perc_of_Listings', Float),
                 Column('Avg_Price', Float),
#                  Column('Center Lat', Double),
#                  Column('Center Lon', Double)

# #                  Column('Min_Price', Float),
#                  Column('Max_Price', Float),
              )

metadata.create_all()
for _t in metadata.tables:
    print("Table: ",_t)
# Out:
# Table:  listings
# Table:  cities

# %%
selection_df.to_sql(name="cities", con=engine, if_exists="append",index=False)
