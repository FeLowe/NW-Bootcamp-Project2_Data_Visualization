# %%
import requests
import json
from pprint import pprint
import numpy as np
import pandas as pd
import os
import csv
import datetime as dt

from sqlalchemy import MetaData
from sqlalchemy import Table
from sqlalchemy import Column
from sqlalchemy import Integer, String, Float

import sqlalchemy
from sqlalchemy import create_engine, func, inspect
from sqlalchemy_utils import database_exists, create_database
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float, Date

from math import radians, sin, cos, asin, sqrt # used to calculate distance of room and city longs and lats

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# Google API Key
# from config import gkey
from flask import Flask, jsonify

# %%
results = requests.get('https://public.opendatasoft.com/api/records/1.0/download/?dataset=air-bnb-listings&rows=100&format=json').json()

# %%
#pprint(results)

# %%
results = [r["fields"] for r in results]
#results

# %%
results_df = pd.DataFrame(results)
results_df.head()
# Out:
#    availability_365  calculated_host_listings_count    city  column_10  \
# 0               292                               7  Lisbon        125
# 1                 0                               1  Lisbon        500
# 2                 0                               1  Lisbon        650
# 3                 0                               1  Lisbon        500
# 4               277                               3  Lisbon         37
#
#   column_19                                          column_20  \
# 0  Portugal                   Portugal, Lisbon, Avenidas Novas
# 1  Portugal                         Portugal, Lisbon, Alcntara
# 2  Portugal           Portugal, Lisbon, So Domingos de Benfica
# 3  Portugal  Portugal, Lisbon, Algs, Linda-a-Velha e Cruz Q...
# 4  Portugal                      Portugal, Lisbon, Misericrdia
#
#                                coordinates   host_id       id last_review  \
# 0  [38.74584282796673, -9.152359763007405]  15282851  2998105  2019-04-17
# 1  [38.70213919994125, -9.177363170810427]  15307946  3003712         NaN
# 2  [38.74499852902329, -9.168202490560926]  15330291  3008031         NaN
# 3  [38.70144477298908, -9.240587547103432]  15415294  3025693         NaN
# 4  [38.71109888002856, -9.148347820132365]  15580486  3063405  2019-04-19
#
#    minimum_nights                                 name  \
# 0               2          Exciting Lisbon Entrecampos
# 1               1  Fantastic Apartment with deck 120m2
# 2               1           Champions League apartment
# 3               1                      Quarto em Algés
# 4               2  Camões Lounge Apartment w/Courtyard
#
#                                  neighbourhood  number_of_reviews  \
# 0                               Avenidas Novas                297
# 1                                     Alcntara                  0
# 2                       So Domingos de Benfica                  0
# 3  Algs, Linda-a-Velha e Cruz Quebrada-Dafundo                  0
# 4                                  Misericrdia                299
#
#    reviews_per_month        room_type updated_date
# 0               4.97  Entire home/apt   2019-04-22
# 1                NaN     Private room   2019-04-22
# 2                NaN  Entire home/apt   2019-04-22
# 3                NaN     Private room   2019-04-22
# 4               5.02  Entire home/apt   2019-04-22

# %%
cleanData = results_df[[ 'column_10','id', 'coordinates', 'room_type', "city", 'column_19']]
cleanData.head()
# Out:
#    column_10       id                              coordinates  \
# 0        125  2998105  [38.74584282796673, -9.152359763007405]
# 1        500  3003712  [38.70213919994125, -9.177363170810427]
# 2        650  3008031  [38.74499852902329, -9.168202490560926]
# 3        500  3025693  [38.70144477298908, -9.240587547103432]
# 4         37  3063405  [38.71109888002856, -9.148347820132365]
#
#          room_type    city column_19
# 0  Entire home/apt  Lisbon  Portugal
# 1     Private room  Lisbon  Portugal
# 2  Entire home/apt  Lisbon  Portugal
# 3     Private room  Lisbon  Portugal
# 4  Entire home/apt  Lisbon  Portugal

# %%
cleanData = cleanData.rename(index=str, columns={"column_10":"Price",
                                                 "id":"Room_Id", 
                                                 "coordinates":"Coordinates",
                                                 "column_19":"Country", 
                                                 "room_type":"Room_Type",
                                                 "city":"City"})

cleanData.head()
# Out:
#    Price  Room_Id                              Coordinates        Room_Type  \
# 0    125  2998105  [38.74584282796673, -9.152359763007405]  Entire home/apt
# 1    500  3003712  [38.70213919994125, -9.177363170810427]     Private room
# 2    650  3008031  [38.74499852902329, -9.168202490560926]  Entire home/apt
# 3    500  3025693  [38.70144477298908, -9.240587547103432]     Private room
# 4     37  3063405  [38.71109888002856, -9.148347820132365]  Entire home/apt
#
#      City   Country
# 0  Lisbon  Portugal
# 1  Lisbon  Portugal
# 2  Lisbon  Portugal
# 3  Lisbon  Portugal
# 4  Lisbon  Portugal

# %%
# Create two lists for the loop results to be placed
lat = []
lon = []

# For each row in a varible,
for row in cleanData['Coordinates']:
   # Try to,
   try:
       # Split the row by comma and append
       # everything before the comma to lat
       lat.append(row[0])
       # Split the row by comma and append
       # everything after the comma to lon
       lon.append(row[1])
   # But if you get an error
   except:
       # append a missing value to lat
       lat.append(np.NaN)
       # append a missing value to lon
       lon.append(np.NaN)

# Create two new columns from lat and lon
cleanData['Room_Lat'] = lat
cleanData['Room_Long'] = lon

# %%
# cleanData = cleanData.drop(columns=["Coordinates"])
# cleanData.head()

# %%
cleanData["Selection"] = cleanData["City"]+", "+cleanData["Country"]
# cleanData.head(5)

# %%
cleanData['City'] = cleanData['City'].str.replace('-',' ')

# %%
rooms_lat = []   # create empty lists
rooms_long = []
cities_lat = [] 
cities_long = []
calculated_distance = []

for index, row in cleanData.iterrows():
    room_lat1 = row['Room_Lat']
    room_long1 = row['Room_Long']
    
# Build the endpoint URL
    gkey = "<KEY>"
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(row, gkey)

#Run a request to endpoint and convert result to json
    cities_lat_long = requests.get(target_url).json()

    city_lat2 = cities_lat_long["results"][0]["geometry"]["location"]["lat"]
    city_long2 = cities_lat_long["results"][0]["geometry"]["location"]["lng"]
    
#CALCULATES DISTANCE OF ROOMS AND CITIES LAT AND LONGS
    def distance(room_long1, room_lat1, city_long2, city_lat2):
        room_long1, room_lat1, city_long2, city_lat2 = map(radians, [room_long1, room_lat1, city_long2, city_lat2])
        dlon = city_long2 - room_long1
        dlat = city_lat2 - room_lat1
        a = sin(dlat / 2) ** 2 + cos(room_lat1) * cos(city_lat2) * sin(dlon / 2) ** 2
        return 2 * 3958.756 * asin(sqrt(a)) #6371 km / 3958.756 for miles

    room_city_distance = distance(room_long1, room_lat1, city_long2, city_lat2)

    rooms_lat.append(room_lat1)
    rooms_long.append(room_long1)
    cities_lat.append(city_lat2)
    cities_long.append(city_long2)
    calculated_distance.append(room_city_distance)
    
print("rooms_lat:", rooms_lat)
print("rooms_long:", rooms_long)
print("cities_lat:", cities_lat)
print("cities_long:", cities_long)
print("calculated_distance:", calculated_distance)

# this site confirmed the calculation is correct:
# https://www.gpsvisualizer.com/calculators
# Out:
# rooms_lat: [38.74584282796673, 38.70213919994125, 38.74499852902329, 38.70144477298908, 38.71109888002856, 38.70824853381608, 38.751007598903335, 38.75894252695615, 38.746816666725785, 38.82631965777253, 38.71694216351822, 39.00386501446866, 38.72084577055854, 38.94581115726129, 38.711728978929635, 38.71308536425166, 38.71580738854452, 38.72775473777788, 38.70730938949486, 38.711248688937985, 38.97143166706441, 38.71715322999262, 38.72231541441824, 38.712737943557215, 38.726883479571555, 38.71062379871473, 38.795819430893125, 39.005962728530676, 38.7464481134842, 38.720637221426024, 38.75089940151426, 38.70530645655638, 38.690300201133766, 38.71248860445329, 38.71208442812792, 38.75765204552851, 38.71740795835646, 38.73086044505078, 38.71395646824652, 38.72385745438006, 38.72675852686154, 38.70914362687136, 38.710019718476204, 38.69055218940939, 38.71497145542667, 38.69463473046933, 38.69974647942219, 38.7084587440487, 38.72591566775218, 38.71470213658233, 38.87050144309989, 38.81469473783082, 38.71624403253538, 38.71347738987339, 38.736526119707364, 38.71293732733293, 38.738320222779656, 38.77446020579742, 39.2662211173286, 38.76907815250579, 38.717486490251574, 38.71090224406195, 38.71504998696641, 38.712832516073874, 38.96414575862678, 38.71588460817811, 38.734019968710356, 38.73169524801226, 38.72367962638119, 38.71738911882399, 38.69824470767308, 38.72694072037514, 38.71801910376107, 38.73454632786042, 38.715409634997705, 38.70962603778424, 39.272952480499754, 38.72530352386295, 38.713462794778955, 39.10350835182846, 38.82034193592283, 38.711025105682026, 38.70265055813432, 38.714738599369724, 38.71989908333498, 38.960757163173824, 38.71772542776206, 38.7068007000865, 38.700400588124715, 38.70821257277977, 38.7257038882291, 38.71932196501728, 38.71348784995498, 38.708858319917816, 38.73294830841642, 38.7101115653184, 38.71132820871602, 38.70997793261707, 38.723136937683336, 38.71337930977499]
# rooms_long: [-9.152359763007405, -9.177363170810427, -9.168202490560926, -9.240587547103432, -9.148347820132365, -9.140954694999623, -9.232284530702461, -9.193017167119498, -9.213504769043555, -9.275936216712273, -9.144230080980554, -9.417173555336705, -9.138784060860642, -9.378442110559691, -9.145715709907442, -9.165641753452698, -9.153494747160583, -9.145553983774237, -9.151403538641247, -9.161112084650627, -9.413313459694292, -9.147204522093235, -9.144484719125197, -9.143353563098838, -9.146672170717824, -9.145755726122562, -9.392047755346479, -9.416885317877034, -9.139516313030407, -9.165643254444307, -9.44566153628253, -9.42925171576516, -9.344857438119968, -9.13522205228532, -9.129914145241495, -9.138832663778153, -9.14849431465629, -9.436399060872846, -9.134287903392213, -9.138851107594762, -9.147616482164239, -9.138696543031882, -9.13935921529278, -9.335405737939208, -9.14461730471207, -9.214926030854235, -9.225181143910715, -9.146451024884012, -9.134999546731278, -9.14704456731228, -9.058088106021982, -9.474705514464901, -9.140382693904046, -9.128622373408295, -9.12100862449187, -9.136113149107963, -9.124002085564715, -9.16292698106999, -9.281277529544104, -9.102518373154082, -9.138747781538088, -9.15064562436264, -9.152508802232378, -9.155183982430144, -9.41469562716954, -9.137892146471675, -9.140099167439086, -9.133870760602756, -9.153312768255896, -9.161733186332208, -9.439235370779757, -9.135149202195201, -9.160988280818355, -9.139105597886648, -9.133961252088424, -9.415309012610047, -9.23545925889285, -9.16568536804404, -9.131346146144278, -9.33981318559401, -9.438551305016585, -9.144428746910664, -9.430544595231336, -9.136531991147294, -9.133334985157983, -9.417281316942296, -9.13966791086446, -9.171070012374702, -9.170612788707144, -9.129424250042224, -9.137929164905728, -9.15906961791891, -9.13642797560232, -9.150558996179434, -9.139431644404121, -9.151322424183856, -9.145841677982904, -9.391273547264067, -9.169726071988679, -9.147414980793751]
# cities_lat: [38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524, 38.7222524]
# cities_long: [-9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366, -9.1393366]
# calculated_distance: [1.7746498887394333, 2.476752594622944, 2.211430851368567, 5.644945931593277, 0.9109735106147058, 0.9714980636974879, 5.3890283355783115, 3.8465037651489586, 4.342788618123457, 10.288019682069983, 0.45189117641174376, 24.53612048923352, 0.10165043393684543, 20.10476725566387, 0.8043234564509413, 1.5531100081026694, 0.883648019905648, 0.5068052925137708, 1.22032278927586, 1.3986081731284754, 22.666523332275705, 0.5513840029732462, 0.27754725650684664, 0.6921346090746261, 0.5086643277691892, 0.874814657975182, 14.53342151033, 24.641683396335406, 1.6717903903756275, 1.4224803491247688, 16.62758457312117, 15.673731551651601, 11.299004320389946, 0.7101435284324324, 0.8669400495968567, 2.4460300403202577, 0.5964451496019135, 16.02344536059256, 0.6345290314327762, 0.113944656175427, 0.5441833039944978, 0.9063857961834668, 0.845197537635921, 10.796107137895444, 0.5780258168866652, 4.500094457166247, 4.882487649070366, 1.0273317782719318, 0.34455664727134394, 0.6669363880908014, 11.138308538370111, 19.162401627612766, 0.4189508218216221, 0.837381566860608, 1.3959023763270237, 0.666656103688337, 1.384067427780621, 3.8246439230477667, 38.349703599161764, 3.7952573637046405, 0.33081887524979503, 0.9933269305134651, 0.8671082110344754, 1.0739982030736284, 22.33633572484587, 0.44680945307877856, 0.8140987722573757, 0.7158745833862178, 0.7598146168085224, 1.2532332988825803, 16.253839895656583, 0.3948164977332743, 1.2032755090192109, 0.8495196244490795, 0.5545267941431404, 14.903364252085822, 38.398184534856505, 1.4358795756035416, 0.7445598574243499, 28.461845679473438, 17.485192956494437, 0.8228721958526977, 15.758240168054343, 0.5407212831781547, 0.362088259641437, 22.255212181036054, 0.313293067741437, 2.0165863802924537, 2.263380504674101, 1.1075110482183999, 0.2502519438665064, 1.082842948583559, 0.6255429344251214, 1.1056569077356317, 0.7390336492364248, 1.0588639281823917, 0.8322788094848611, 13.608464395573376, 1.6392968026977095, 0.7520074064915712]

# %%
# cleanData['City_Lat'] = cities_lat
# cleanData['City_Long'] = cities_long
cleanData['Calc_Distance'] = calculated_distance

cleanData.head()
# Out:
#    Price  Room_Id                              Coordinates        Room_Type  \
# 0    125  2998105  [38.74584282796673, -9.152359763007405]  Entire home/apt
# 1    500  3003712  [38.70213919994125, -9.177363170810427]     Private room
# 2    650  3008031  [38.74499852902329, -9.168202490560926]  Entire home/apt
# 3    500  3025693  [38.70144477298908, -9.240587547103432]     Private room
# 4     37  3063405  [38.71109888002856, -9.148347820132365]  Entire home/apt
#
#      City   Country   Room_Lat  Room_Long         Selection  Calc_Distance
# 0  Lisbon  Portugal  38.745843  -9.152360  Lisbon, Portugal       1.774650
# 1  Lisbon  Portugal  38.702139  -9.177363  Lisbon, Portugal       2.476753
# 2  Lisbon  Portugal  38.744999  -9.168202  Lisbon, Portugal       2.211431
# 3  Lisbon  Portugal  38.701445  -9.240588  Lisbon, Portugal       5.644946
# 4  Lisbon  Portugal  38.711099  -9.148348  Lisbon, Portugal       0.910974

# %%
cleanData= cleanData.drop(columns=["Coordinates"])
cleanData.head()
# Out:
#    Price  Room_Id        Room_Type    City   Country   Room_Lat  Room_Long  \
# 0    125  2998105  Entire home/apt  Lisbon  Portugal  38.745843  -9.152360
# 1    500  3003712     Private room  Lisbon  Portugal  38.702139  -9.177363
# 2    650  3008031  Entire home/apt  Lisbon  Portugal  38.744999  -9.168202
# 3    500  3025693     Private room  Lisbon  Portugal  38.701445  -9.240588
# 4     37  3063405  Entire home/apt  Lisbon  Portugal  38.711099  -9.148348
#
#           Selection  Calc_Distance
# 0  Lisbon, Portugal       1.774650
# 1  Lisbon, Portugal       2.476753
# 2  Lisbon, Portugal       2.211431
# 3  Lisbon, Portugal       5.644946
# 4  Lisbon, Portugal       0.910974

# %%
# #Export city names to csv
# cleanData.to_csv('../data.csv', index=False)

# # Import cities file as DataFrame
# cleanData_df = pd.read_csv("../data.csv")
# cleanData_df.head()

# %%
# this site confirmed the calculation is correct:
# https://www.gpsvisualizer.com/calculators

# %%
cleanData = cleanData.rename(index=str, columns={"Room_Lat":"Latitude",
                                                 "Room_Long":"Longitude", 
                                                 "Calc_Distance":"Distance"})

cleanData.head()
# Out:
#    Price  Room_Id                              Coordinates        Room_Type  \
# 0    125  2998105  [38.74584282796673, -9.152359763007405]  Entire home/apt
# 1    500  3003712  [38.70213919994125, -9.177363170810427]     Private room
# 2    650  3008031  [38.74499852902329, -9.168202490560926]  Entire home/apt
# 3    500  3025693  [38.70144477298908, -9.240587547103432]     Private room
# 4     37  3063405  [38.71109888002856, -9.148347820132365]  Entire home/apt
#
#      City   Country   Latitude  Longitude         Selection
# 0  Lisbon  Portugal  38.745843  -9.152360  Lisbon, Portugal
# 1  Lisbon  Portugal  38.702139  -9.177363  Lisbon, Portugal
# 2  Lisbon  Portugal  38.744999  -9.168202  Lisbon, Portugal
# 3  Lisbon  Portugal  38.701445  -9.240588  Lisbon, Portugal
# 4  Lisbon  Portugal  38.711099  -9.148348  Lisbon, Portugal

# %%
conn_str = "root:sinkybay@localhost/airbnb_data"
engine = create_engine(f'mysql://{conn_str}')

if not database_exists(engine.url):
    create_database(engine.url)

# %%
engine.table_names()
# Out:
# ['listings']

# %%
metadata = MetaData(engine)

listings = Table('listings', metadata,
                 Column('Price', Integer),
                 Column('Room_Id', String(10)),
                 Column('Room_Type', String(25)),
                 Column('City', String(50)),
                 Column('Country', String(50)),
                 Column('Latitude', Float),
                 Column('Longitude', Float),
                 Column('Selection', String(100)),
                 Column('Distance', Float))

metadata.create_all()
for _t in metadata.tables:
    print("Table: ",_t)
# Out:
# Table:  listings

# %%
cleanData.to_sql(name="listings", con=engine, if_exists="append",index=False)

# %%
selection_count_listings= cleanData.groupby(['Selection']).count()

selection_sum= cleanData.groupby(['Selection']).sum()

selection_sum
# total_rooms= len(cleanData["Room_Id"].unique())
# ?total_price = cleanData["Price"].sum()

# selection = pd.DataFrame(cleanData["Selection"].unique())

# city_listings = selection["Room_Id"].count()
# city_rooms_perc = total_rooms/city_rooms
city_price = selection["Price"].sum()
# city_avg_price = total_price / city_price



# len(purchase_df["Item ID"].unique())

# selection_df = pd.DataFrame({"#Rooms":room_count,"Avg Price":avg_price/player_count*100})
# gender_demog_df["Percentage of players"] = gender_demog_df["Percentage of players"].map("{:.0f}".format)

# print("# of Rooms:", total_rooms)
# print("Total price:", total_price)
# print("# of rooms per city:", city_listings)
# print("% of rooms per city :", city_rooms_perc)
# print("city price sum:", city_price)
# print("Room avg price:", city_avg_price)
# selection.head()

# selection_df = pd.DataFrame({"#Rooms":room_count,"Avg Price":avg_price/player_count*100})
# gender_demog_df["Percentage of players"] = gender_demog_df["Percentage of players"].map("{:.0f}".format)
# Out:
#                   Price    Room_Id     Latitude   Longitude
# Selection
# Lisbon, Portugal  11925  547319015  3875.515354 -920.259888

# %%
selection_df = pd.DataFrame(cleanData["Selection"].unique())

selection_df["# of Listings"] = total_rooms
selection_df["# of listings per city"] = city_listings
selection_df
# Out:
#                   0  # of Listings  # of listings per city
# 0  Lisbon, Portugal            100                       2
# 1               100            100                       2

# %%
cityList = pd.read_sql_query('select distinct Selection from listings', con=engine)
cityList.head
# Out:
# <bound method NDFrame.head of           Selection
# 0  Lisbon, Portugal>

# %%
cities = Table('cities', metadata,
                 Column('Selection', String(100))
              )

metadata.create_all()
for _t in metadata.tables:
    print("Table: ",_t)
# Out:
# Table:  listings
# Table:  cities

# %%
cityList.to_sql(name="cities", con=engine, if_exists="append",index=False)
