# %%
import requests
import json
from pprint import pprint
import numpy as np
import pandas as pd
import os
import datetime as dt

import sqlalchemy
from sqlalchemy import create_engine, func, inspect
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float, Date

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session


from flask import Flask, jsonify

# %%
results = requests.get('https://public.opendatasoft.com/api/records/1.0/download/?dataset=air-bnb-listings&rows=1000&format=json').json()
pprint(results)
# Out:
# [{'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 292,
#              'calculated_host_listings_count': 7,
#              'city': 'Lisbon',
#              'column_10': 125,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Avenidas Novas',
#              'coordinates': [38.74584282796673, -9.152359763007405],
#              'host_id': 15282851,
#              'id': 2998105,
#              'last_review': '2019-04-17',
#              'minimum_nights': 2,
#              'name': 'Exciting Lisbon Entrecampos',
#              'neighbourhood': 'Avenidas Novas',
#              'number_of_reviews': 297,
#              'reviews_per_month': 4.97,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.152359763007405, 38.74584282796673],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '64d5c2753e54fa16731ea8f7cf03163b079eb035'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 500,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Alcntara',
#              'coordinates': [38.70213919994125, -9.177363170810427],
#              'host_id': 15307946,
#              'id': 3003712,
#              'minimum_nights': 1,
#              'name': 'Fantastic Apartment with deck 120m2',
#              'neighbourhood': 'Alcntara',
#              'number_of_reviews': 0,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.177363170810427, 38.70213919994125],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '33e33624e78acf6a439ea268704a78aaf3aaacdc'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 650,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, So Domingos de Benfica',
#              'coordinates': [38.74499852902329, -9.168202490560926],
#              'host_id': 15330291,
#              'id': 3008031,
#              'minimum_nights': 1,
#              'name': 'Champions League apartment',
#              'neighbourhood': 'So Domingos de Benfica',
#              'number_of_reviews': 0,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.168202490560926, 38.74499852902329],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '1fca366b305dfa6b07cfb57f4551594c3bb1488c'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 500,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Algs, Linda-a-Velha e Cruz '
#                           'Quebrada-Dafundo',
#              'coordinates': [38.70144477298908, -9.240587547103432],
#              'host_id': 15415294,
#              'id': 3025693,
#              'minimum_nights': 1,
#              'name': 'Quarto em Algés',
#              'neighbourhood': 'Algs, Linda-a-Velha e Cruz Quebrada-Dafundo',
#              'number_of_reviews': 0,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.240587547103432, 38.70144477298908],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'ddd57fd1c1132e1692307668968cc1eb9618d514'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 277,
#              'calculated_host_listings_count': 3,
#              'city': 'Lisbon',
#              'column_10': 37,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Misericrdia',
#              'coordinates': [38.71109888002856, -9.148347820132365],
#              'host_id': 15580486,
#              'id': 3063405,
#              'last_review': '2019-04-19',
#              'minimum_nights': 2,
#              'name': 'Camões Lounge Apartment w/Courtyard',
#              'neighbourhood': 'Misericrdia',
#              'number_of_reviews': 299,
#              'reviews_per_month': 5.02,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.148347820132365, 38.71109888002856],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'f73e54b5efaab5e7c5afe52e126316f4fa499d45'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 1200,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#              'coordinates': [38.70824853381608, -9.140954694999623],
#              'host_id': 15733441,
#              'id': 3096570,
#              'minimum_nights': 1,
#              'name': 'Alugo de 24 a 25 Champions League',
#              'neighbourhood': 'Santa Maria Maior',
#              'number_of_reviews': 0,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.140954694999623, 38.70824853381608],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '056571e251f584f1efcb2e912fe9da115dcd6c69'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 500,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Venteira',
#              'coordinates': [38.751007598903335, -9.232284530702461],
#              'host_id': 15826178,
#              'id': 3114625,
#              'minimum_nights': 1,
#              'name': 'Quarto/Final UEFA CUP Lisboa',
#              'neighbourhood': 'Venteira',
#              'number_of_reviews': 0,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.232284530702461, 38.751007598903335],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'd62d3c2ff682e132f4167fc07a5515d3146f211f'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 2,
#              'city': 'Lisbon',
#              'column_10': 800,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Carnide',
#              'coordinates': [38.75894252695615, -9.193017167119498],
#              'host_id': 15830223,
#              'id': 3115589,
#              'minimum_nights': 1,
#              'name': 'Room for Champions League',
#              'neighbourhood': 'Carnide',
#              'number_of_reviews': 0,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.193017167119498, 38.75894252695615],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'e2dc484b13a8e268b2d0c22ae87667391db8021d'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 1000,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, guas Livres',
#              'coordinates': [38.746816666725785, -9.213504769043555],
#              'host_id': 15871370,
#              'id': 3124693,
#              'minimum_nights': 1,
#              'name': "Lisbon -Champions Final 10''Stadium",
#              'neighbourhood': 'guas Livres',
#              'number_of_reviews': 0,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.213504769043555, 38.746816666725785],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'a0bead43c0b3ad84417dcc29c8a45c0872fa0c70'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 22,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 320,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Almargem do Bispo, Pro Pinheiro e '
#                           'Montelavar',
#              'coordinates': [38.82631965777253, -9.275936216712273],
#              'host_id': 15916831,
#              'id': 3134497,
#              'last_review': '2018-10-07',
#              'minimum_nights': 2,
#              'name': 'Villa cerrado das fontainhas',
#              'neighbourhood': 'Almargem do Bispo, Pro Pinheiro e Montelavar',
#              'number_of_reviews': 17,
#              'reviews_per_month': 0.72,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.275936216712273, 38.82631965777253],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'eccd530bfb087ff15ad61927b4f28a446ac22cd9'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 305,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 56,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santo Antnio',
#              'coordinates': [38.71694216351822, -9.144230080980554],
#              'host_id': 16260490,
#              'id': 3209351,
#              'last_review': '2019-04-18',
#              'minimum_nights': 3,
#              'name': 'Apartamento Centro histórico 4 pessoas',
#              'neighbourhood': 'Santo Antnio',
#              'number_of_reviews': 152,
#              'reviews_per_month': 2.67,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.144230080980554, 38.71694216351822],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '63823758910ae08e309ea2c8e63b4d85b6065ea3'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 154,
#              'calculated_host_listings_count': 7,
#              'city': 'Lisbon',
#              'column_10': 45,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santo Isidoro',
#              'coordinates': [39.00386501446866, -9.417173555336705],
#              'host_id': 16279104,
#              'id': 3257471,
#              'last_review': '2017-08-05',
#              'minimum_nights': 1,
#              'name': 'THE COMMUNITY SURF HOSTEL Twin room',
#              'neighbourhood': 'Santo Isidoro',
#              'number_of_reviews': 3,
#              'reviews_per_month': 0.05,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.417173555336705, 39.00386501446866],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '4b3e15fe0e118d654370f52b16196f54a5ec3d2b'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 246,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 70,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Arroios',
#              'coordinates': [38.72084577055854, -9.138784060860642],
#              'host_id': 16508134,
#              'id': 3264550,
#              'last_review': '2019-04-17',
#              'minimum_nights': 2,
#              'name': 'Apartamento, Centro de Lisboa',
#              'neighbourhood': 'Arroios',
#              'number_of_reviews': 152,
#              'reviews_per_month': 2.59,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.138784060860642, 38.72084577055854],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '04f8e1b663f637592d76e6727b178d9dad6bd9a0'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 118,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 140,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Mafra',
#              'coordinates': [38.94581115726129, -9.378442110559691],
#              'host_id': 16659152,
#              'id': 3297998,
#              'last_review': '2018-10-11',
#              'minimum_nights': 7,
#              'name': "Stunning Villa 'Duas Vistas'",
#              'neighbourhood': 'Mafra',
#              'number_of_reviews': 17,
#              'reviews_per_month': 0.29,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.378442110559691, 38.94581115726129],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '42a13de0b412011a5871d92d4af580071eda3e79'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 325,
#              'calculated_host_listings_count': 4,
#              'city': 'Lisbon',
#              'column_10': 105,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Misericrdia',
#              'coordinates': [38.711728978929635, -9.145715709907442],
#              'host_id': 17035707,
#              'id': 3376720,
#              'last_review': '2019-03-24',
#              'minimum_nights': 2,
#              'name': 'Bica / Chiado - Garden House',
#              'neighbourhood': 'Misericrdia',
#              'number_of_reviews': 138,
#              'reviews_per_month': 2.89,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.145715709907442, 38.711728978929635],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '44f90cd7276c25106a7e50adb023f02b0cf85bc9'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 141,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 45,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Campo de Ourique',
#              'coordinates': [38.71308536425166, -9.165641753452698],
#              'host_id': 17047228,
#              'id': 3379202,
#              'last_review': '2019-04-09',
#              'minimum_nights': 3,
#              'name': 'Jardim de Ourique em Lisboa',
#              'neighbourhood': 'Campo de Ourique',
#              'number_of_reviews': 69,
#              'reviews_per_month': 1.19,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.165641753452698, 38.71308536425166],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'dc87a4f9483ada2e97959aa439f768344622dfcb'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 188,
#              'calculated_host_listings_count': 9,
#              'city': 'Lisbon',
#              'column_10': 50,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Misericrdia',
#              'coordinates': [38.71580738854452, -9.153494747160583],
#              'host_id': 3753184,
#              'id': 3379203,
#              'last_review': '2019-04-16',
#              'minimum_nights': 3,
#              'name': 'Relax in Flowers Garden Apartment',
#              'neighbourhood': 'Misericrdia',
#              'number_of_reviews': 309,
#              'reviews_per_month': 5.3,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.153494747160583, 38.71580738854452],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'c20e4b302a5ab3b6b1ed09f483a3129478ceca42'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 10,
#              'city': 'Lisbon',
#              'column_10': 105,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santo Antnio',
#              'coordinates': [38.72775473777788, -9.145553983774237],
#              'host_id': 7665008,
#              'id': 3547303,
#              'last_review': '2018-08-30',
#              'minimum_nights': 3,
#              'name': 'Sunny Apartment with suite rooms!',
#              'neighbourhood': 'Santo Antnio',
#              'number_of_reviews': 23,
#              'reviews_per_month': 0.51,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.145553983774237, 38.72775473777788],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '13a6f5cc7be34ca096e6022493282c9b94843622'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 301,
#              'calculated_host_listings_count': 16,
#              'city': 'Lisbon',
#              'column_10': 29,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Misericrdia',
#              'coordinates': [38.70730938949486, -9.151403538641247],
#              'host_id': 10487625,
#              'id': 3620611,
#              'last_review': '2019-03-30',
#              'minimum_nights': 2,
#              'name': 'SantoSweethome 3B',
#              'neighbourhood': 'Misericrdia',
#              'number_of_reviews': 244,
#              'reviews_per_month': 4.24,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.151403538641247, 38.70730938949486],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '4cdfd8abb814074ef49073296e2e4607f823d620'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 121,
#              'calculated_host_listings_count': 31,
#              'city': 'Lisbon',
#              'column_10': 10,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Estrela',
#              'coordinates': [38.711248688937985, -9.161112084650627],
#              'host_id': 11470182,
#              'id': 3638077,
#              'last_review': '2019-03-31',
#              'minimum_nights': 1,
#              'name': 'Rooftop SurfHouse - Sunshine Room',
#              'neighbourhood': 'Estrela',
#              'number_of_reviews': 369,
#              'reviews_per_month': 6.42,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.161112084650627, 38.711248688937985],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'a12ed4daf32f42c922fbe0eeb8a7e57a5f6cb520'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 334,
#              'calculated_host_listings_count': 17,
#              'city': 'Lisbon',
#              'column_10': 85,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Ericeira',
#              'coordinates': [38.97143166706441, -9.413313459694292],
#              'host_id': 17206393,
#              'id': 3672984,
#              'last_review': '2018-06-17',
#              'minimum_nights': 1,
#              'name': 'Villa Sunrise - Golden Halcyon Ericeira Villas',
#              'neighbourhood': 'Ericeira',
#              'number_of_reviews': 2,
#              'reviews_per_month': 0.04,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.413313459694292, 38.97143166706441],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'c68658d670a7fa420f97eb40f755876860b2e97c'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 302,
#              'calculated_host_listings_count': 2,
#              'city': 'Lisbon',
#              'column_10': 55,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santo Antnio',
#              'coordinates': [38.71715322999262, -9.147204522093235],
#              'host_id': 18710963,
#              'id': 3681323,
#              'last_review': '2018-10-01',
#              'minimum_nights': 1,
#              'name': 'New SPOT- P. Real/Bairro Alto',
#              'neighbourhood': 'Santo Antnio',
#              'number_of_reviews': 6,
#              'reviews_per_month': 0.12,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.147204522093235, 38.71715322999262],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '9fc100e9e5b0964ada5aeb89adaf237a464ea77b'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 346,
#              'calculated_host_listings_count': 2,
#              'city': 'Lisbon',
#              'column_10': 34,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santo Antnio',
#              'coordinates': [38.72231541441824, -9.144484719125197],
#              'host_id': 18650677,
#              'id': 3724685,
#              'last_review': '2019-04-14',
#              'minimum_nights': 1,
#              'name': 'Avenida da Liberdade w/garden.',
#              'neighbourhood': 'Santo Antnio',
#              'number_of_reviews': 211,
#              'reviews_per_month': 3.78,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.144484719125197, 38.72231541441824],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '3b0e17968de418fa7bd332cf96edf0ca44e1d36c'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 358,
#              'calculated_host_listings_count': 15,
#              'city': 'Lisbon',
#              'column_10': 50,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Misericrdia',
#              'coordinates': [38.712737943557215, -9.143353563098838],
#              'host_id': 19455234,
#              'id': 3790282,
#              'last_review': '2019-04-02',
#              'minimum_nights': 3,
#              'name': 'Bairro Alto lounge',
#              'neighbourhood': 'Misericrdia',
#              'number_of_reviews': 100,
#              'reviews_per_month': 1.76,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.143353563098838, 38.712737943557215],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '90a97eacfb5012e62f7b4ee9bc69ce603d7dfdd8'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 20,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santo Antnio',
#              'coordinates': [38.726883479571555, -9.146672170717824],
#              'host_id': 19683926,
#              'id': 3825830,
#              'minimum_nights': 1,
#              'name': 'Room for two',
#              'neighbourhood': 'Santo Antnio',
#              'number_of_reviews': 0,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.146672170717824, 38.726883479571555],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'ea2395fcfa6fbc48c737d57a2d812d1929bb0015'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 239,
#              'calculated_host_listings_count': 2,
#              'city': 'Lisbon',
#              'column_10': 45,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Misericrdia',
#              'coordinates': [38.71062379871473, -9.145755726122562],
#              'host_id': 2717587,
#              'id': 3861604,
#              'last_review': '2019-04-13',
#              'minimum_nights': 2,
#              'name': 'Live In Chiado House Fast WI-FI',
#              'neighbourhood': 'Misericrdia',
#              'number_of_reviews': 268,
#              'reviews_per_month': 4.73,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.145755726122562, 38.71062379871473],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '0ffabc7dc6bb6577c45b6d2e91e4684bba680d22'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 293,
#              'calculated_host_listings_count': 2,
#              'city': 'Lisbon',
#              'column_10': 59,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, S.Maria, S.Miguel, S.Martinho, '
#                           'S.Pedro Penaferrim',
#              'coordinates': [38.795819430893125, -9.392047755346479],
#              'host_id': 17981201,
#              'id': 3948409,
#              'last_review': '2019-04-05',
#              'minimum_nights': 1,
#              'name': 'Chez Fleur -  Sintra',
#              'neighbourhood': 'S.Maria, S.Miguel, S.Martinho, S.Pedro '
#                               'Penaferrim',
#              'number_of_reviews': 126,
#              'reviews_per_month': 3.52,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.392047755346479, 38.795819430893125],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '3007248548c328521048fbf6ef7f2b9ccbf43f61'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 295,
#              'calculated_host_listings_count': 6,
#              'city': 'Lisbon',
#              'column_10': 75,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santo Isidoro',
#              'coordinates': [39.005962728530676, -9.416885317877034],
#              'host_id': 20598151,
#              'id': 4031174,
#              'last_review': '2018-08-22',
#              'minimum_nights': 2,
#              'name': 'Vilas de Ribamar - Red House Ericeira',
#              'neighbourhood': 'Santo Isidoro',
#              'number_of_reviews': 10,
#              'reviews_per_month': 0.22,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.416885317877034, 39.005962728530676],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'f51a580ace0b47320bed6f6b508a8cd3a0cdf77d'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 184,
#              'calculated_host_listings_count': 2,
#              'city': 'Lisbon',
#              'column_10': 44,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Alvalade',
#              'coordinates': [38.7464481134842, -9.139516313030407],
#              'host_id': 20947228,
#              'id': 4040135,
#              'last_review': '2019-04-05',
#              'minimum_nights': 3,
#              'name': 'Lisboa Trendy',
#              'neighbourhood': 'Alvalade',
#              'number_of_reviews': 48,
#              'reviews_per_month': 0.88,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.139516313030407, 38.7464481134842],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '877e4f616d7bb4fa80173395783c6c46c8fa6acb'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 365,
#              'calculated_host_listings_count': 3,
#              'city': 'Lisbon',
#              'column_10': 80,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Campo de Ourique',
#              'coordinates': [38.720637221426024, -9.165643254444307],
#              'host_id': 18817546,
#              'id': 4071765,
#              'minimum_nights': 1,
#              'name': 'O melhor e central bairro de Lx',
#              'neighbourhood': 'Campo de Ourique',
#              'number_of_reviews': 0,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.165643254444307, 38.720637221426024],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '2c11d65bfe7e477605fb31f29640abdc6c11d95a'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 42,
#              'calculated_host_listings_count': 14,
#              'city': 'Lisbon',
#              'column_10': 250,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Alcabideche',
#              'coordinates': [38.75089940151426, -9.44566153628253],
#              'host_id': 21200870,
#              'id': 4095389,
#              'minimum_nights': 3,
#              'name': 'Morada Sol - Villa Sintra by Sol Domus',
#              'neighbourhood': 'Alcabideche',
#              'number_of_reviews': 0,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.44566153628253, 38.75089940151426],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'dbb693df6b7035e7d7ce6c60da91dd05239b5ebf'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 305,
#              'calculated_host_listings_count': 3,
#              'city': 'Lisbon',
#              'column_10': 35,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Cascais e Estoril',
#              'coordinates': [38.70530645655638, -9.42925171576516],
#              'host_id': 21252772,
#              'id': 4097489,
#              'last_review': '2019-04-21',
#              'minimum_nights': 3,
#              'name': 'Apartamento Cascais',
#              'neighbourhood': 'Cascais e Estoril',
#              'number_of_reviews': 73,
#              'reviews_per_month': 1.32,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.42925171576516, 38.70530645655638],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '3330378ac565f26e5be47bf2a6fe0e4126eed76b'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 343,
#              'calculated_host_listings_count': 3,
#              'city': 'Lisbon',
#              'column_10': 15,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Carcavelos e Parede',
#              'coordinates': [38.690300201133766, -9.344857438119968],
#              'host_id': 21479461,
#              'id': 4140385,
#              'last_review': '2017-05-14',
#              'minimum_nights': 6,
#              'name': 'Room 10 m from sea & beach & surf&train',
#              'neighbourhood': 'Carcavelos e Parede',
#              'number_of_reviews': 3,
#              'reviews_per_month': 0.05,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.344857438119968, 38.690300201133766],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'dfbf5af7d5dd3425ad05cfea81967087ef4f9e5c'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 318,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 40,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#              'coordinates': [38.71248860445329, -9.13522205228532],
#              'host_id': 21808331,
#              'id': 4203561,
#              'last_review': '2019-04-20',
#              'minimum_nights': 2,
#              'name': 'Apartamento Castelo Baixa Chiado',
#              'neighbourhood': 'Santa Maria Maior',
#              'number_of_reviews': 121,
#              'reviews_per_month': 2.52,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.13522205228532, 38.71248860445329],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '973fdcd09da81ac4664762e02614b8f5d9e7f5f4'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 206,
#              'calculated_host_listings_count': 3,
#              'city': 'Lisbon',
#              'column_10': 55,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#              'coordinates': [38.71208442812792, -9.129914145241495],
#              'host_id': 9774669,
#              'id': 4276547,
#              'last_review': '2019-04-19',
#              'minimum_nights': 2,
#              'name': 'You&Alfama',
#              'neighbourhood': 'Santa Maria Maior',
#              'number_of_reviews': 183,
#              'reviews_per_month': 3.38,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.129914145241495, 38.71208442812792],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'e6e0054ba95a4af7528ff1f4f7911527747c1a75'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 220,
#              'calculated_host_listings_count': 2,
#              'city': 'Lisbon',
#              'column_10': 20,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Alvalade',
#              'coordinates': [38.75765204552851, -9.138832663778153],
#              'host_id': 17124100,
#              'id': 4292024,
#              'last_review': '2018-11-11',
#              'minimum_nights': 2,
#              'name': 'Comfortable room near the airport',
#              'neighbourhood': 'Alvalade',
#              'number_of_reviews': 145,
#              'reviews_per_month': 2.76,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.138832663778153, 38.75765204552851],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '6439f18ad4620e7bb0c97a3127257797a18456d5'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 152,
#              'calculated_host_listings_count': 6,
#              'city': 'Lisbon',
#              'column_10': 55,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santo Antnio',
#              'coordinates': [38.71740795835646, -9.14849431465629],
#              'host_id': 1695029,
#              'id': 4451346,
#              'last_review': '2019-04-05',
#              'minimum_nights': 3,
#              'name': 'House with a view in Príncipe Real',
#              'neighbourhood': 'Santo Antnio',
#              'number_of_reviews': 179,
#              'reviews_per_month': 3.3,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.14849431465629, 38.71740795835646],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'dba70bd34fee7898718568023d826f44b8546f64'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 53,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Alcabideche',
#              'coordinates': [38.73086044505078, -9.436399060872846],
#              'host_id': 4970288,
#              'id': 4631671,
#              'last_review': '2016-10-05',
#              'minimum_nights': 3,
#              'name': 'Lovely house – Guincho Beach',
#              'neighbourhood': 'Alcabideche',
#              'number_of_reviews': 6,
#              'reviews_per_month': 0.12,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.436399060872846, 38.73086044505078],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'a624cd7015cabac44ff6a77156ec56e0be99dd9d'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 344,
#              'calculated_host_listings_count': 12,
#              'city': 'Lisbon',
#              'column_10': 35,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#              'coordinates': [38.71395646824652, -9.134287903392213],
#              'host_id': 24627664,
#              'id': 4775560,
#              'last_review': '2018-11-03',
#              'minimum_nights': 2,
#              'name': 'LISBOA, MARTIM MONIZ 31, Downtown',
#              'neighbourhood': 'Santa Maria Maior',
#              'number_of_reviews': 68,
#              'reviews_per_month': 1.3,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.134287903392213, 38.71395646824652],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'ba3a3b9918d4ab167896159aff01219944a49057'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 137,
#              'calculated_host_listings_count': 2,
#              'city': 'Lisbon',
#              'column_10': 60,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Arroios',
#              'coordinates': [38.72385745438006, -9.138851107594762],
#              'host_id': 10497993,
#              'id': 4776251,
#              'last_review': '2019-02-02',
#              'minimum_nights': 2,
#              'name': 'Urban Flat Village',
#              'neighbourhood': 'Arroios',
#              'number_of_reviews': 145,
#              'reviews_per_month': 2.78,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.138851107594762, 38.72385745438006],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '53e019511904c0fd30c75bc8ee710a3f5cb7e92d'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 283,
#              'calculated_host_listings_count': 3,
#              'city': 'Lisbon',
#              'column_10': 130,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santo Antnio',
#              'coordinates': [38.72675852686154, -9.147616482164239],
#              'host_id': 24755412,
#              'id': 4805505,
#              'last_review': '2018-11-20',
#              'minimum_nights': 3,
#              'name': 'Casa Pimenta - Home away from home',
#              'neighbourhood': 'Santo Antnio',
#              'number_of_reviews': 28,
#              'reviews_per_month': 0.57,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.147616482164239, 38.72675852686154],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '89573a4c975aa297303d265ff149e97c4596b3dd'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 295,
#              'calculated_host_listings_count': 5,
#              'city': 'Lisbon',
#              'column_10': 70,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#              'coordinates': [38.70914362687136, -9.138696543031882],
#              'host_id': 24654595,
#              'id': 4981325,
#              'last_review': '2016-10-09',
#              'minimum_nights': 7,
#              'name': 'A double room in center of Lisboa',
#              'neighbourhood': 'Santa Maria Maior',
#              'number_of_reviews': 2,
#              'reviews_per_month': 0.06,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.138696543031882, 38.70914362687136],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'c6f5992b1301ca8d93afb373c440ee6e80bc7ba9'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 308,
#              'calculated_host_listings_count': 6,
#              'city': 'Lisbon',
#              'column_10': 70,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#              'coordinates': [38.710019718476204, -9.13935921529278],
#              'host_id': 25239614,
#              'id': 5003402,
#              'last_review': '2019-04-14',
#              'minimum_nights': 1,
#              'name': 'Contemporary Ap in Chiado 2 - w/ central heating.',
#              'neighbourhood': 'Santa Maria Maior',
#              'number_of_reviews': 107,
#              'reviews_per_month': 2.66,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.13935921529278, 38.710019718476204],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'bb4b0dd100313f250ea51159ca955292ffb786f2'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 288,
#              'calculated_host_listings_count': 5,
#              'city': 'Lisbon',
#              'column_10': 30,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Carcavelos e Parede',
#              'coordinates': [38.69055218940939, -9.335405737939208],
#              'host_id': 5788339,
#              'id': 5053634,
#              'last_review': '2019-03-01',
#              'minimum_nights': 3,
#              'name': 'LISBON BEACH CHALÉ @ CARCAVELOS',
#              'neighbourhood': 'Carcavelos e Parede',
#              'number_of_reviews': 37,
#              'reviews_per_month': 0.73,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.335405737939208, 38.69055218940939],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '25477d9545dce7f078213b8ed9b03dc2bfa99b9f'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 164,
#              'calculated_host_listings_count': 4,
#              'city': 'Lisbon',
#              'column_10': 48,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Misericrdia',
#              'coordinates': [38.71497145542667, -9.14461730471207],
#              'host_id': 2730513,
#              'id': 5314270,
#              'last_review': '2019-04-09',
#              'minimum_nights': 2,
#              'name': 'Trendy Loft in the heart of the city!',
#              'neighbourhood': 'Misericrdia',
#              'number_of_reviews': 193,
#              'reviews_per_month': 3.89,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.14461730471207, 38.71497145542667],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '5e08b7b290657b3fe733ce59f1cf155fd60872dc'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 146,
#              'calculated_host_listings_count': 4,
#              'city': 'Lisbon',
#              'column_10': 88,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Belm',
#              'coordinates': [38.69463473046933, -9.214926030854235],
#              'host_id': 25690714,
#              'id': 5339378,
#              'last_review': '2018-07-29',
#              'minimum_nights': 1,
#              'name': 'Cozy double room with balcony',
#              'neighbourhood': 'Belm',
#              'number_of_reviews': 22,
#              'reviews_per_month': 0.46,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.214926030854235, 38.69463473046933],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '096140ee3353c276d83bdc48af71bf8db8fd3363'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 356,
#              'calculated_host_listings_count': 2,
#              'city': 'Lisbon',
#              'column_10': 85,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Belm',
#              'coordinates': [38.69974647942219, -9.225181143910715],
#              'host_id': 28283287,
#              'id': 5453275,
#              'last_review': '2017-10-13',
#              'minimum_nights': 2,
#              'name': 'LISBOA / SANTA MARIA DE BELÉM',
#              'neighbourhood': 'Belm',
#              'number_of_reviews': 2,
#              'reviews_per_month': 0.07,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.225181143910715, 38.69974647942219],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'ac3725fce60c597b80bcc7ffb78dbfa654e0d70f'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 307,
#              'calculated_host_listings_count': 13,
#              'city': 'Lisbon',
#              'column_10': 51,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Misericrdia',
#              'coordinates': [38.7084587440487, -9.146451024884012],
#              'host_id': 3250665,
#              'id': 5477637,
#              'last_review': '2019-03-30',
#              'minimum_nights': 2,
#              'name': 'Saint Paul, Third Floor',
#              'neighbourhood': 'Misericrdia',
#              'number_of_reviews': 86,
#              'reviews_per_month': 1.73,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.146451024884012, 38.7084587440487],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '92486b01a1925cfd2caa6318ad6322a6d4c64685'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 334,
#              'calculated_host_listings_count': 68,
#              'city': 'Lisbon',
#              'column_10': 230,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Arroios',
#              'coordinates': [38.72591566775218, -9.134999546731278],
#              'host_id': 2372087,
#              'id': 5769351,
#              'last_review': '2018-09-17',
#              'minimum_nights': 2,
#              'name': 'ALMIRANTE TOP FLOOR',
#              'neighbourhood': 'Arroios',
#              'number_of_reviews': 31,
#              'reviews_per_month': 0.65,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.134999546731278, 38.72591566775218],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'ef68b2e55b7ecb52719809ea32aafbfb23206e5a'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 297,
#              'calculated_host_listings_count': 13,
#              'city': 'Lisbon',
#              'column_10': 60,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Misericrdia',
#              'coordinates': [38.71470213658233, -9.14704456731228],
#              'host_id': 21019651,
#              'id': 5789942,
#              'last_review': '2019-03-28',
#              'minimum_nights': 2,
#              'name': 'Charming Chiado House W/ AC + Free Pickup',
#              'neighbourhood': 'Misericrdia',
#              'number_of_reviews': 249,
#              'reviews_per_month': 5.1,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.14704456731228, 38.71470213658233],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '0fd95ab5008df93f9f3dcf2373aa0a7f317539b2'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 81,
#              'calculated_host_listings_count': 3,
#              'city': 'Lisbon',
#              'column_10': 79,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Pvoa de Santa Iria e Forte da '
# ...
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '4b1773daa6904763b789b84c2f9d62f63f2d6e02'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 233,
#              'calculated_host_listings_count': 108,
#              'city': 'Hawaii',
#              'column_10': 795,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, Lahaina',
#              'coordinates': [20.94377124553496, -156.69136974948634],
#              'host_id': 39073224,
#              'id': 15235203,
#              'last_review': '2018-10-19',
#              'minimum_nights': 5,
#              'name': 'Maui Resort Rentals: Honua Kai Hokulani 618',
#              'neighbourhood': 'Lahaina',
#              'number_of_reviews': 3,
#              'reviews_per_month': 0.18,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-156.69136974948634, 20.94377124553496],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '0daaa14a8ee2e56a04eaf5884e1e56119afa81a4'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 259,
#              'calculated_host_listings_count': 212,
#              'city': 'Hawaii',
#              'column_10': 257,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, North Kona',
#              'coordinates': [19.62073376963632, -155.98574321764715],
#              'host_id': 18476866,
#              'id': 15236676,
#              'last_review': '2019-03-25',
#              'minimum_nights': 1,
#              'name': 'Alii Villas #128 2BD/2BA Ocean View',
#              'neighbourhood': 'North Kona',
#              'number_of_reviews': 6,
#              'reviews_per_month': 0.24,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-155.98574321764715, 19.62073376963632],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'd2694eddfd5bc41d721043115c11f553ff982e6e'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 2,
#              'calculated_host_listings_count': 2,
#              'city': 'Hawaii',
#              'column_10': 49,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, Primary Urban Center',
#              'coordinates': [21.2823459664176, -157.82696149887445],
#              'host_id': 64469977,
#              'id': 15278282,
#              'last_review': '2017-02-06',
#              'minimum_nights': 30,
#              'name': 'Great nicely studio in Wakiki',
#              'neighbourhood': 'Primary Urban Center',
#              'number_of_reviews': 1,
#              'reviews_per_month': 0.04,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-157.82696149887445, 21.2823459664176],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '417c4b8dbfa0824321f709c6ea4c9a8b6fc01903'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 181,
#              'calculated_host_listings_count': 119,
#              'city': 'Hawaii',
#              'column_10': 263,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, Koloa-Poipu',
#              'coordinates': [21.87676975991982, -159.44783222931167],
#              'host_id': 97006413,
#              'id': 15286440,
#              'last_review': '2018-08-04',
#              'minimum_nights': 3,
#              'name': 'Poipu Panoramic Ocean View A/C Bedrooms *Kahala 614*',
#              'neighbourhood': 'Koloa-Poipu',
#              'number_of_reviews': 2,
#              'reviews_per_month': 0.18,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-159.44783222931167, 21.87676975991982],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '9cd3457b647d699c394666c5788092baf5f3b95d'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 284,
#              'calculated_host_listings_count': 119,
#              'city': 'Hawaii',
#              'column_10': 206,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, Koloa-Poipu',
#              'coordinates': [21.874552494531212, -159.44989668268727],
#              'host_id': 97006413,
#              'id': 15286506,
#              'last_review': '2018-05-06',
#              'minimum_nights': 3,
#              'name': 'Poipu Ground Floor w/Perfect Garden View A/C Living '
#                      'Room*Manualoha 1103*',
#              'neighbourhood': 'Koloa-Poipu',
#              'number_of_reviews': 2,
#              'reviews_per_month': 0.08,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-159.44989668268727, 21.874552494531212],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '1fbe3c900e1a507f6bc6684128b21744a55b6c72'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 256,
#              'calculated_host_listings_count': 119,
#              'city': 'Hawaii',
#              'column_10': 320,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, Koloa-Poipu',
#              'coordinates': [21.874569753851745, -159.44598344415346],
#              'host_id': 97006413,
#              'id': 15286573,
#              'last_review': '2019-04-11',
#              'minimum_nights': 3,
#              'name': 'Poipu Peaceful Garden Retreat Pool/Jacuzzi AC in the '
#                      'Master Suite & Loft *Regency 321*',
#              'neighbourhood': 'Koloa-Poipu',
#              'number_of_reviews': 2,
#              'reviews_per_month': 0.1,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-159.44598344415346, 21.874569753851745],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '0434ba5aadd06b291c298593c97aad4f616628f2'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 274,
#              'calculated_host_listings_count': 119,
#              'city': 'Hawaii',
#              'column_10': 286,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, Koloa-Poipu',
#              'coordinates': [21.876871248167, -159.44717678611846],
#              'host_id': 97006413,
#              'id': 15286587,
#              'last_review': '2018-08-03',
#              'minimum_nights': 3,
#              'name': 'Poipu Spacious Bright Family Condo in Poipu Kai *Regency '
#                      '520*',
#              'neighbourhood': 'Koloa-Poipu',
#              'number_of_reviews': 2,
#              'reviews_per_month': 0.2,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-159.44717678611846, 21.876871248167],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'c431a70daa760490a1f451de59c510f9a2775ef2'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 293,
#              'calculated_host_listings_count': 1,
#              'city': 'Hawaii',
#              'column_10': 100,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, East Honolulu',
#              'coordinates': [21.31019215248727, -157.6832694911966],
#              'host_id': 67295903,
#              'id': 15347210,
#              'last_review': '2019-03-27',
#              'minimum_nights': 5,
#              'name': "Hale Ho'o Kipa",
#              'neighbourhood': 'East Honolulu',
#              'number_of_reviews': 58,
#              'reviews_per_month': 2.19,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-157.6832694911966, 21.31019215248727],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '039202d668d3541c2f4081360dd17e91ae5b476a'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 233,
#              'calculated_host_listings_count': 2,
#              'city': 'Hawaii',
#              'column_10': 185,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, Kihei-Makena',
#              'coordinates': [20.71431143258302, -156.44573755220037],
#              'host_id': 61821986,
#              'id': 15358684,
#              'last_review': '2019-03-12',
#              'minimum_nights': 7,
#              'name': 'Gorgeous 2 bedroom 2 bath spacious condo 9-402',
#              'neighbourhood': 'Kihei-Makena',
#              'number_of_reviews': 25,
#              'reviews_per_month': 0.81,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-156.44573755220037, 20.71431143258302],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '7d1283fa4efa1e47302601db8fc4c3d9eda31237'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 247,
#              'calculated_host_listings_count': 53,
#              'city': 'Hawaii',
#              'column_10': 575,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, South Kohala',
#              'coordinates': [20.00713504455208, -155.80802121154915],
#              'host_id': 96255708,
#              'id': 15409191,
#              'minimum_nights': 4,
#              'name': '❤️PiH❤️ Beautiful Ocean Villa ★ Gorgeous Views',
#              'neighbourhood': 'South Kohala',
#              'number_of_reviews': 0,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-155.80802121154915, 20.00713504455208],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '461db3cbd4e4483d8b70f7ea105ca601bff9250e'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 119,
#              'calculated_host_listings_count': 1,
#              'city': 'Hawaii',
#              'column_10': 400,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, Lahaina',
#              'coordinates': [20.971204091867673, -156.6769286756077],
#              'host_id': 12735119,
#              'id': 15451995,
#              'last_review': '2018-12-28',
#              'minimum_nights': 7,
#              'name': 'Your Dream Vacation in Maui- for the holidays',
#              'neighbourhood': 'Lahaina',
#              'number_of_reviews': 2,
#              'reviews_per_month': 0.07,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-156.6769286756077, 20.971204091867673],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'bc7cd8d5bd415e30d103ecf20bad4c1e71b9d7c4'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 363,
#              'calculated_host_listings_count': 1,
#              'city': 'Hawaii',
#              'column_10': 199,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, Primary Urban Center',
#              'coordinates': [21.285688601770286, -157.83491421598353],
#              'host_id': 17939795,
#              'id': 15468300,
#              'minimum_nights': 30,
#              'name': 'Great Views - Great Vacation Rental 5 min to Beach',
#              'neighbourhood': 'Primary Urban Center',
#              'number_of_reviews': 0,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-157.83491421598353, 21.285688601770286],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'bb8817d73cc4e0c8f2e2e2a1caca4eedaa56c35f'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 236,
#              'calculated_host_listings_count': 82,
#              'city': 'Hawaii',
#              'column_10': 431,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, North Shore Kauai',
#              'coordinates': [22.221131347251017, -159.4873729072357],
#              'host_id': 47208806,
#              'id': 15482342,
#              'last_review': '2018-10-11',
#              'minimum_nights': 5,
#              'name': 'AC, Hot Tub, BBQ, & Shared Pool',
#              'neighbourhood': 'North Shore Kauai',
#              'number_of_reviews': 14,
#              'reviews_per_month': 0.47,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-159.4873729072357, 22.221131347251017],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '247d62ecd3ebe7cf657d96f57f5c21efbe630e75'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 238,
#              'calculated_host_listings_count': 94,
#              'city': 'Hawaii',
#              'column_10': 345,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, Primary Urban Center',
#              'coordinates': [21.26157051506708, -157.8205586893975],
#              'host_id': 43793840,
#              'id': 15499008,
#              'last_review': '2019-03-02',
#              'minimum_nights': 2,
#              'name': 'Well Appointed Penthouse Private Ocean Lanai 1401',
#              'neighbourhood': 'Primary Urban Center',
#              'number_of_reviews': 21,
#              'reviews_per_month': 0.71,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-157.8205586893975, 21.26157051506708],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '5e10e04214e2c67366a34e8f5cd0ee6866cddd25'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 321,
#              'calculated_host_listings_count': 1,
#              'city': 'Hawaii',
#              'column_10': 180,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, South Hilo',
#              'coordinates': [19.712502836305408, -155.0674001795268],
#              'host_id': 21267026,
#              'id': 15605384,
#              'last_review': '2019-04-28',
#              'minimum_nights': 1,
#              'name': 'House w/Yard in Hilo, close to Everything, 3bd2bth',
#              'neighbourhood': 'South Hilo',
#              'number_of_reviews': 91,
#              'reviews_per_month': 3.18,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-155.0674001795268, 19.712502836305408],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '13efcf463009d5d6cb7cedb5f1bebfc67c1ca50f'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 266,
#              'calculated_host_listings_count': 16,
#              'city': 'Hawaii',
#              'column_10': 119,
#              'column_19': 'United states',
#              'column_20': 'United states, Hawaii, Koolaupoko',
#              'coordinates': [21.393282382366266, -157.73465857685534],
#              'host_id': 26157559,
#              'id': 15635430,
#              'last_review': '2019-04-28',
#              'minimum_nights': 1,
#              'name': "D&D's B&B- sweet island style Studio",
#              'neighbourhood': 'Koolaupoko',
#              'number_of_reviews': 37,
#              'reviews_per_month': 1.21,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-05-03'},
#   'geometry': {'coordinates': [-157.73465857685534, 21.393282382366266],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '22546c76a7f51313b0c00a971f4a8541c12b1507'}]

# %%
type(results)
# Out:
# list

# %%
results = [r["fields"] for r in results]
results
# Out:
# [{'updated_date': '2019-04-22',
#   'reviews_per_month': 4.97,
#   'calculated_host_listings_count': 7,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.74584282796673, -9.152359763007405],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 297,
#   'column_10': 125,
#   'neighbourhood': 'Avenidas Novas',
#   'last_review': '2019-04-17',
#   'host_id': 15282851,
#   'column_19': 'Portugal',
#   'availability_365': 292,
#   'id': 2998105,
#   'column_20': 'Portugal, Lisbon, Avenidas Novas',
#   'name': 'Exciting Lisbon Entrecampos'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.70213919994125, -9.177363170810427],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 500,
#   'neighbourhood': 'Alcntara',
#   'host_id': 15307946,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3003712,
#   'column_20': 'Portugal, Lisbon, Alcntara',
#   'name': 'Fantastic Apartment with deck 120m2'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.74499852902329, -9.168202490560926],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 650,
#   'neighbourhood': 'So Domingos de Benfica',
#   'host_id': 15330291,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3008031,
#   'column_20': 'Portugal, Lisbon, So Domingos de Benfica',
#   'name': 'Champions League apartment'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.70144477298908, -9.240587547103432],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 500,
#   'neighbourhood': 'Algs, Linda-a-Velha e Cruz Quebrada-Dafundo',
#   'host_id': 15415294,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3025693,
#   'column_20': 'Portugal, Lisbon, Algs, Linda-a-Velha e Cruz Quebrada-Dafundo',
#   'name': 'Quarto em Algés'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 5.02,
#   'calculated_host_listings_count': 3,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71109888002856, -9.148347820132365],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 299,
#   'column_10': 37,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-04-19',
#   'host_id': 15580486,
#   'column_19': 'Portugal',
#   'availability_365': 277,
#   'id': 3063405,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Camões Lounge Apartment w/Courtyard'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.70824853381608, -9.140954694999623],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 1200,
#   'neighbourhood': 'Santa Maria Maior',
#   'host_id': 15733441,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3096570,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'Alugo de 24 a 25 Champions League'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.751007598903335, -9.232284530702461],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 500,
#   'neighbourhood': 'Venteira',
#   'host_id': 15826178,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3114625,
#   'column_20': 'Portugal, Lisbon, Venteira',
#   'name': 'Quarto/Final UEFA CUP Lisboa'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 2,
#   'minimum_nights': 1,
#   'coordinates': [38.75894252695615, -9.193017167119498],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 800,
#   'neighbourhood': 'Carnide',
#   'host_id': 15830223,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3115589,
#   'column_20': 'Portugal, Lisbon, Carnide',
#   'name': 'Room for Champions League'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.746816666725785, -9.213504769043555],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 1000,
#   'neighbourhood': 'guas Livres',
#   'host_id': 15871370,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3124693,
#   'column_20': 'Portugal, Lisbon, guas Livres',
#   'name': "Lisbon -Champions Final 10''Stadium"},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.72,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.82631965777253, -9.275936216712273],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 17,
#   'column_10': 320,
#   'neighbourhood': 'Almargem do Bispo, Pro Pinheiro e Montelavar',
#   'last_review': '2018-10-07',
#   'host_id': 15916831,
#   'column_19': 'Portugal',
#   'availability_365': 22,
#   'id': 3134497,
#   'column_20': 'Portugal, Lisbon, Almargem do Bispo, Pro Pinheiro e Montelavar',
#   'name': 'Villa cerrado das fontainhas'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.67,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.71694216351822, -9.144230080980554],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 152,
#   'column_10': 56,
#   'neighbourhood': 'Santo Antnio',
#   'last_review': '2019-04-18',
#   'host_id': 16260490,
#   'column_19': 'Portugal',
#   'availability_365': 305,
#   'id': 3209351,
#   'column_20': 'Portugal, Lisbon, Santo Antnio',
#   'name': 'Apartamento Centro histórico 4 pessoas'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.05,
#   'calculated_host_listings_count': 7,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [39.00386501446866, -9.417173555336705],
#   'room_type': 'Private room',
#   'number_of_reviews': 3,
#   'column_10': 45,
#   'neighbourhood': 'Santo Isidoro',
#   'last_review': '2017-08-05',
#   'host_id': 16279104,
#   'column_19': 'Portugal',
#   'availability_365': 154,
#   'id': 3257471,
#   'column_20': 'Portugal, Lisbon, Santo Isidoro',
#   'name': 'THE COMMUNITY SURF HOSTEL Twin room'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.59,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.72084577055854, -9.138784060860642],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 152,
#   'column_10': 70,
#   'neighbourhood': 'Arroios',
#   'last_review': '2019-04-17',
#   'host_id': 16508134,
#   'column_19': 'Portugal',
#   'availability_365': 246,
#   'id': 3264550,
#   'column_20': 'Portugal, Lisbon, Arroios',
#   'name': 'Apartamento, Centro de Lisboa'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.29,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 7,
#   'coordinates': [38.94581115726129, -9.378442110559691],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 17,
#   'column_10': 140,
#   'neighbourhood': 'Mafra',
#   'last_review': '2018-10-11',
#   'host_id': 16659152,
#   'column_19': 'Portugal',
#   'availability_365': 118,
#   'id': 3297998,
#   'column_20': 'Portugal, Lisbon, Mafra',
#   'name': "Stunning Villa 'Duas Vistas'"},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.89,
#   'calculated_host_listings_count': 4,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.711728978929635, -9.145715709907442],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 138,
#   'column_10': 105,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-03-24',
#   'host_id': 17035707,
#   'column_19': 'Portugal',
#   'availability_365': 325,
#   'id': 3376720,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Bica / Chiado - Garden House'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 1.19,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.71308536425166, -9.165641753452698],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 69,
#   'column_10': 45,
#   'neighbourhood': 'Campo de Ourique',
#   'last_review': '2019-04-09',
#   'host_id': 17047228,
#   'column_19': 'Portugal',
#   'availability_365': 141,
#   'id': 3379202,
#   'column_20': 'Portugal, Lisbon, Campo de Ourique',
#   'name': 'Jardim de Ourique em Lisboa'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 5.3,
#   'calculated_host_listings_count': 9,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.71580738854452, -9.153494747160583],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 309,
#   'column_10': 50,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-04-16',
#   'host_id': 3753184,
#   'column_19': 'Portugal',
#   'availability_365': 188,
#   'id': 3379203,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Relax in Flowers Garden Apartment'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.51,
#   'calculated_host_listings_count': 10,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.72775473777788, -9.145553983774237],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 23,
#   'column_10': 105,
#   'neighbourhood': 'Santo Antnio',
#   'last_review': '2018-08-30',
#   'host_id': 7665008,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3547303,
#   'column_20': 'Portugal, Lisbon, Santo Antnio',
#   'name': 'Sunny Apartment with suite rooms!'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 4.24,
#   'calculated_host_listings_count': 16,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.70730938949486, -9.151403538641247],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 244,
#   'column_10': 29,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-03-30',
#   'host_id': 10487625,
#   'column_19': 'Portugal',
#   'availability_365': 301,
#   'id': 3620611,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'SantoSweethome 3B'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 6.42,
#   'calculated_host_listings_count': 31,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.711248688937985, -9.161112084650627],
#   'room_type': 'Private room',
#   'number_of_reviews': 369,
#   'column_10': 10,
#   'neighbourhood': 'Estrela',
#   'last_review': '2019-03-31',
#   'host_id': 11470182,
#   'column_19': 'Portugal',
#   'availability_365': 121,
#   'id': 3638077,
#   'column_20': 'Portugal, Lisbon, Estrela',
#   'name': 'Rooftop SurfHouse - Sunshine Room'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.04,
#   'calculated_host_listings_count': 17,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.97143166706441, -9.413313459694292],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 2,
#   'column_10': 85,
#   'neighbourhood': 'Ericeira',
#   'last_review': '2018-06-17',
#   'host_id': 17206393,
#   'column_19': 'Portugal',
#   'availability_365': 334,
#   'id': 3672984,
#   'column_20': 'Portugal, Lisbon, Ericeira',
#   'name': 'Villa Sunrise - Golden Halcyon Ericeira Villas'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.12,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.71715322999262, -9.147204522093235],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 6,
#   'column_10': 55,
#   'neighbourhood': 'Santo Antnio',
#   'last_review': '2018-10-01',
#   'host_id': 18710963,
#   'column_19': 'Portugal',
#   'availability_365': 302,
#   'id': 3681323,
#   'column_20': 'Portugal, Lisbon, Santo Antnio',
#   'name': 'New SPOT- P. Real/Bairro Alto'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 3.78,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.72231541441824, -9.144484719125197],
#   'room_type': 'Private room',
#   'number_of_reviews': 211,
#   'column_10': 34,
#   'neighbourhood': 'Santo Antnio',
#   'last_review': '2019-04-14',
#   'host_id': 18650677,
#   'column_19': 'Portugal',
#   'availability_365': 346,
#   'id': 3724685,
#   'column_20': 'Portugal, Lisbon, Santo Antnio',
#   'name': 'Avenida da Liberdade w/garden.'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 1.76,
#   'calculated_host_listings_count': 15,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.712737943557215, -9.143353563098838],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 100,
#   'column_10': 50,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-04-02',
#   'host_id': 19455234,
#   'column_19': 'Portugal',
#   'availability_365': 358,
#   'id': 3790282,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Bairro Alto lounge'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.726883479571555, -9.146672170717824],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 20,
#   'neighbourhood': 'Santo Antnio',
#   'host_id': 19683926,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3825830,
#   'column_20': 'Portugal, Lisbon, Santo Antnio',
#   'name': 'Room for two'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 4.73,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71062379871473, -9.145755726122562],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 268,
#   'column_10': 45,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-04-13',
#   'host_id': 2717587,
#   'column_19': 'Portugal',
#   'availability_365': 239,
#   'id': 3861604,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Live In Chiado House Fast WI-FI'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 3.52,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.795819430893125, -9.392047755346479],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 126,
#   'column_10': 59,
#   'neighbourhood': 'S.Maria, S.Miguel, S.Martinho, S.Pedro Penaferrim',
#   'last_review': '2019-04-05',
#   'host_id': 17981201,
#   'column_19': 'Portugal',
#   'availability_365': 293,
#   'id': 3948409,
#   'column_20': 'Portugal, Lisbon, S.Maria, S.Miguel, S.Martinho, S.Pedro Penaferrim',
#   'name': 'Chez Fleur -  Sintra'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.22,
#   'calculated_host_listings_count': 6,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [39.005962728530676, -9.416885317877034],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 10,
#   'column_10': 75,
#   'neighbourhood': 'Santo Isidoro',
#   'last_review': '2018-08-22',
#   'host_id': 20598151,
#   'column_19': 'Portugal',
#   'availability_365': 295,
#   'id': 4031174,
#   'column_20': 'Portugal, Lisbon, Santo Isidoro',
#   'name': 'Vilas de Ribamar - Red House Ericeira'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.88,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.7464481134842, -9.139516313030407],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 48,
#   'column_10': 44,
#   'neighbourhood': 'Alvalade',
#   'last_review': '2019-04-05',
#   'host_id': 20947228,
#   'column_19': 'Portugal',
#   'availability_365': 184,
#   'id': 4040135,
#   'column_20': 'Portugal, Lisbon, Alvalade',
#   'name': 'Lisboa Trendy'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 3,
#   'minimum_nights': 1,
#   'coordinates': [38.720637221426024, -9.165643254444307],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 80,
#   'neighbourhood': 'Campo de Ourique',
#   'host_id': 18817546,
#   'column_19': 'Portugal',
#   'availability_365': 365,
#   'id': 4071765,
#   'column_20': 'Portugal, Lisbon, Campo de Ourique',
#   'name': 'O melhor e central bairro de Lx'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 14,
#   'minimum_nights': 3,
#   'coordinates': [38.75089940151426, -9.44566153628253],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 250,
#   'neighbourhood': 'Alcabideche',
#   'host_id': 21200870,
#   'column_19': 'Portugal',
#   'availability_365': 42,
#   'id': 4095389,
#   'column_20': 'Portugal, Lisbon, Alcabideche',
#   'name': 'Morada Sol - Villa Sintra by Sol Domus'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 1.32,
#   'calculated_host_listings_count': 3,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.70530645655638, -9.42925171576516],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 73,
#   'column_10': 35,
#   'neighbourhood': 'Cascais e Estoril',
#   'last_review': '2019-04-21',
#   'host_id': 21252772,
#   'column_19': 'Portugal',
#   'availability_365': 305,
#   'id': 4097489,
#   'column_20': 'Portugal, Lisbon, Cascais e Estoril',
#   'name': 'Apartamento Cascais'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.05,
#   'calculated_host_listings_count': 3,
#   'city': 'Lisbon',
#   'minimum_nights': 6,
#   'coordinates': [38.690300201133766, -9.344857438119968],
#   'room_type': 'Private room',
#   'number_of_reviews': 3,
#   'column_10': 15,
#   'neighbourhood': 'Carcavelos e Parede',
#   'last_review': '2017-05-14',
#   'host_id': 21479461,
#   'column_19': 'Portugal',
#   'availability_365': 343,
#   'id': 4140385,
#   'column_20': 'Portugal, Lisbon, Carcavelos e Parede',
#   'name': 'Room 10 m from sea & beach & surf&train'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.52,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71248860445329, -9.13522205228532],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 121,
#   'column_10': 40,
#   'neighbourhood': 'Santa Maria Maior',
#   'last_review': '2019-04-20',
#   'host_id': 21808331,
#   'column_19': 'Portugal',
#   'availability_365': 318,
#   'id': 4203561,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'Apartamento Castelo Baixa Chiado'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 3.38,
#   'calculated_host_listings_count': 3,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71208442812792, -9.129914145241495],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 183,
#   'column_10': 55,
#   'neighbourhood': 'Santa Maria Maior',
#   'last_review': '2019-04-19',
#   'host_id': 9774669,
#   'column_19': 'Portugal',
#   'availability_365': 206,
#   'id': 4276547,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'You&Alfama'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.76,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.75765204552851, -9.138832663778153],
#   'room_type': 'Private room',
#   'number_of_reviews': 145,
#   'column_10': 20,
#   'neighbourhood': 'Alvalade',
#   'last_review': '2018-11-11',
#   'host_id': 17124100,
#   'column_19': 'Portugal',
#   'availability_365': 220,
#   'id': 4292024,
#   'column_20': 'Portugal, Lisbon, Alvalade',
#   'name': 'Comfortable room near the airport'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 3.3,
#   'calculated_host_listings_count': 6,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.71740795835646, -9.14849431465629],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 179,
#   'column_10': 55,
#   'neighbourhood': 'Santo Antnio',
#   'last_review': '2019-04-05',
#   'host_id': 1695029,
#   'column_19': 'Portugal',
#   'availability_365': 152,
#   'id': 4451346,
#   'column_20': 'Portugal, Lisbon, Santo Antnio',
#   'name': 'House with a view in Príncipe Real'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.12,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.73086044505078, -9.436399060872846],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 6,
#   'column_10': 53,
#   'neighbourhood': 'Alcabideche',
#   'last_review': '2016-10-05',
#   'host_id': 4970288,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 4631671,
#   'column_20': 'Portugal, Lisbon, Alcabideche',
#   'name': 'Lovely house – Guincho Beach'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 1.3,
#   'calculated_host_listings_count': 12,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71395646824652, -9.134287903392213],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 68,
#   'column_10': 35,
#   'neighbourhood': 'Santa Maria Maior',
#   'last_review': '2018-11-03',
#   'host_id': 24627664,
#   'column_19': 'Portugal',
#   'availability_365': 344,
#   'id': 4775560,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'LISBOA, MARTIM MONIZ 31, Downtown'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.78,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.72385745438006, -9.138851107594762],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 145,
#   'column_10': 60,
#   'neighbourhood': 'Arroios',
#   'last_review': '2019-02-02',
#   'host_id': 10497993,
#   'column_19': 'Portugal',
#   'availability_365': 137,
#   'id': 4776251,
#   'column_20': 'Portugal, Lisbon, Arroios',
#   'name': 'Urban Flat Village'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.57,
#   'calculated_host_listings_count': 3,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.72675852686154, -9.147616482164239],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 28,
#   'column_10': 130,
#   'neighbourhood': 'Santo Antnio',
#   'last_review': '2018-11-20',
#   'host_id': 24755412,
#   'column_19': 'Portugal',
#   'availability_365': 283,
#   'id': 4805505,
#   'column_20': 'Portugal, Lisbon, Santo Antnio',
#   'name': 'Casa Pimenta - Home away from home'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.06,
#   'calculated_host_listings_count': 5,
#   'city': 'Lisbon',
#   'minimum_nights': 7,
#   'coordinates': [38.70914362687136, -9.138696543031882],
#   'room_type': 'Private room',
#   'number_of_reviews': 2,
#   'column_10': 70,
#   'neighbourhood': 'Santa Maria Maior',
#   'last_review': '2016-10-09',
#   'host_id': 24654595,
#   'column_19': 'Portugal',
#   'availability_365': 295,
#   'id': 4981325,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'A double room in center of Lisboa'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.66,
#   'calculated_host_listings_count': 6,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.710019718476204, -9.13935921529278],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 107,
#   'column_10': 70,
#   'neighbourhood': 'Santa Maria Maior',
#   'last_review': '2019-04-14',
#   'host_id': 25239614,
#   'column_19': 'Portugal',
#   'availability_365': 308,
#   'id': 5003402,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'Contemporary Ap in Chiado 2 - w/ central heating.'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.73,
#   'calculated_host_listings_count': 5,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.69055218940939, -9.335405737939208],
#   'room_type': 'Private room',
#   'number_of_reviews': 37,
#   'column_10': 30,
#   'neighbourhood': 'Carcavelos e Parede',
#   'last_review': '2019-03-01',
#   'host_id': 5788339,
#   'column_19': 'Portugal',
#   'availability_365': 288,
#   'id': 5053634,
#   'column_20': 'Portugal, Lisbon, Carcavelos e Parede',
#   'name': 'LISBON BEACH CHALÉ @ CARCAVELOS'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 3.89,
#   'calculated_host_listings_count': 4,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71497145542667, -9.14461730471207],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 193,
#   'column_10': 48,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-04-09',
#   'host_id': 2730513,
#   'column_19': 'Portugal',
#   'availability_365': 164,
#   'id': 5314270,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Trendy Loft in the heart of the city!'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.46,
#   'calculated_host_listings_count': 4,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.69463473046933, -9.214926030854235],
#   'room_type': 'Private room',
#   'number_of_reviews': 22,
#   'column_10': 88,
#   'neighbourhood': 'Belm',
#   'last_review': '2018-07-29',
#   'host_id': 25690714,
#   'column_19': 'Portugal',
#   'availability_365': 146,
#   'id': 5339378,
#   'column_20': 'Portugal, Lisbon, Belm',
#   'name': 'Cozy double room with balcony'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.07,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.69974647942219, -9.225181143910715],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 2,
#   'column_10': 85,
#   'neighbourhood': 'Belm',
#   'last_review': '2017-10-13',
#   'host_id': 28283287,
#   'column_19': 'Portugal',
#   'availability_365': 356,
#   'id': 5453275,
#   'column_20': 'Portugal, Lisbon, Belm',
#   'name': 'LISBOA / SANTA MARIA DE BELÉM'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 1.73,
#   'calculated_host_listings_count': 13,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.7084587440487, -9.146451024884012],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 86,
#   'column_10': 51,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-03-30',
#   'host_id': 3250665,
#   'column_19': 'Portugal',
#   'availability_365': 307,
#   'id': 5477637,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Saint Paul, Third Floor'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.65,
#   'calculated_host_listings_count': 68,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.72591566775218, -9.134999546731278],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 31,
#   'column_10': 230,
#   'neighbourhood': 'Arroios',
#   'last_review': '2018-09-17',
#   'host_id': 2372087,
#   'column_19': 'Portugal',
#   'availability_365': 334,
#   'id': 5769351,
#   'column_20': 'Portugal, Lisbon, Arroios',
#   'name': 'ALMIRANTE TOP FLOOR'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 5.1,
#   'calculated_host_listings_count': 13,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71470213658233, -9.14704456731228],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 249,
#   'column_10': 60,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-03-28',
#   'host_id': 21019651,
#   'column_19': 'Portugal',
#   'availability_365': 297,
#   'id': 5789942,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Charming Chiado House W/ AC + Free Pickup'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.42,
#   'calculated_host_listings_count': 3,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.87050144309989, -9.058088106021982],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 20,
#   'column_10': 79,
#   'neighbourhood': 'Pvoa de Santa Iria e Forte da Casa',
#   'last_review': '2018-11-28',
#   'host_id': 30228572,
#   'column_19': 'Portugal',
#   'availability_365': 81,
#   'id': 5823942,
#   'column_20': 'Portugal, Lisbon, Pvoa de Santa Iria e Forte da Casa',
#   'name': 'Relaxing Sunset Lisbon 15min Airpor'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.13,
#   'calculated_host_listings_count': 13,
#   'city': 'Lisbon',
#   'minimum_nights': 7,
#   'coordinates': [38.81469473783082, -9.474705514464901],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 6,
#   'column_10': 350,
#   'neighbourhood': 'Colares',
#   'last_review': '2018-06-30',
#   'host_id': 776635,
#   'column_19': 'Portugal',
#   'availability_365': 114,
#   'id': 5926409,
#   'column_20': 'Portugal, Lisbon, Colares',
#   'name': 'Villa Praia Grande'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.75,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.71624403253538, -9.140382693904046],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 133,
#   'column_10': 95,
#   'neighbourhood': 'Arroios',
#   'last_review': '2019-02-10',
#   'host_id': 31080498,
#   'column_19': 'Portugal',
#   'availability_365': 279,
#   'id': 5986364,
#   'column_20': 'Portugal, Lisbon, Arroios',
#   'name': 'Fantastic F3 in the heart of Lisbon'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 4.14,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71347738987339, -9.128622373408295],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 200,
#   'column_10': 50,
#   'neighbourhood': 'So Vicente',
#   'last_review': '2018-12-27',
#   'host_id': 3863464,
#   'column_19': 'Portugal',
#   'availability_365': 111,
#   'id': 6023734,
#   'column_20': 'Portugal, Lisbon, So Vicente',
#   'name': 'Charming Studio in Alfama'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.42,
#   'calculated_host_listings_count': 14,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.736526119707364, -9.12100862449187],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 112,
#   'column_10': 50,
#   'neighbourhood': 'Beato',
#   'last_review': '2019-04-08',
#   'host_id': 31352532,
#   'column_19': 'Portugal',
#   'availability_365': 250,
#   'id': 6073971,
#   'column_20': 'Portugal, Lisbon, Beato',
#   'name': 'Water and Sun III'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.17,
#   'calculated_host_listings_count': 191,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71293732733293, -9.136113149107963],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 8,
#   'column_10': 52,
#   'neighbourhood': 'Santa Maria Maior',
#   'last_review': '2018-08-22',
#   'host_id': 1756107,
#   'column_19': 'Portugal',
#   'availability_365': 253,
#   'id': 6099448,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'Downtown Cosy Apartment |RentExperience'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 1.84,
#   'calculated_host_listings_count': 14,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.738320222779656, -9.124002085564715],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 61,
#   'column_10': 50,
#   'neighbourhood': 'Beato',
#   'last_review': '2019-03-28',
#   'host_id': 31352532,
#   'column_19': 'Portugal',
#   'availability_365': 335,
#   'id': 6113609,
#   'column_20': 'Portugal, Lisbon, Beato',
#   'name': 'Acqua e sole I'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.18,
#   'calculated_host_listings_count': 11,
#   'city': 'Lisbon',
#   'minimum_nights': 4,
#   'coordinates': [38.77446020579742, -9.16292698106999],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 7,
#   'column_10': 65,
#   'neighbourhood': 'Lumiar',
#   'last_review': '2018-06-03',
#   'host_id': 20893300,
#   'column_19': 'Portugal',
#   'availability_365': 112,
#   'id': 6116227,
#   'column_20': 'Portugal, Lisbon, Lumiar',
#   'name': 'Casa Rainha Santa Isabel, Lisboa'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.07,
#   'calculated_host_listings_count': 14,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [39.2662211173286, -9.281277529544104],
#   'room_type': 'Private room',
#   'number_of_reviews': 3,
#   'column_10': 69,
#   'neighbourhood': 'Lourinh e Atalaia',
#   'last_review': '2018-09-27',
#   'host_id': 17235600,
#   'column_19': 'Portugal',
#   'availability_365': 179,
#   'id': 6144300,
#   'column_20': 'Portugal, Lisbon, Lourinh e Atalaia',
#   'name': 'The Maverick - Triple Attic Room'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 1.3,
#   'calculated_host_listings_count': 9,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.76907815250579, -9.102518373154082],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 59,
#   'column_10': 66,
#   'neighbourhood': 'Parque das Naes',
#   'last_review': '2019-04-21',
#   'host_id': 15262500,
#   'column_19': 'Portugal',
#   'availability_365': 306,
#   'id': 6273183,
#   'column_20': 'Portugal, Lisbon, Parque das Naes',
#   'name': 'ORIENTE DNA TRAVEL APT 3 BY W2Lx'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.88,
#   'calculated_host_listings_count': 6,
#   'city': 'Lisbon',
#   'minimum_nights': 4,
#   'coordinates': [38.717486490251574, -9.138747781538088],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 41,
#   'column_10': 75,
#   'neighbourhood': 'Arroios',
#   'last_review': '2018-08-01',
#   'host_id': 20507987,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 6296164,
#   'column_20': 'Portugal, Lisbon, Arroios',
#   'name': 'Charming Lisboeta Pod Apt, Downtown Lisboa'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 4.22,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.71090224406195, -9.15064562436264],
#   'room_type': 'Private room',
#   'number_of_reviews': 201,
#   'column_10': 22,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-04-07',
#   'host_id': 15803788,
#   'column_19': 'Portugal',
#   'availability_365': 104,
#   'id': 6298021,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Sunny Room in Bairro Alto/Bica'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 4.12,
#   'calculated_host_listings_count': 7,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71504998696641, -9.152508802232378],
#   'room_type': 'Private room',
#   'number_of_reviews': 197,
#   'column_10': 37,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-04-18',
#   'host_id': 32184037,
#   'column_19': 'Portugal',
#   'availability_365': 70,
#   'id': 6315156,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Living Simply Lisbon 5'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 7,
#   'minimum_nights': 2,
#   'coordinates': [38.712832516073874, -9.155183982430144],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 68,
#   'neighbourhood': 'Estrela',
#   'host_id': 31663982,
#   'column_19': 'Portugal',
#   'availability_365': 219,
#   'id': 6487376,
#   'column_20': 'Portugal, Lisbon, Estrela',
#   'name': '#6 Suite Fernando Pessoa (w/ Private WC)'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.39,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.96414575862678, -9.41469562716954],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 13,
#   'column_10': 45,
#   'neighbourhood': 'Ericeira',
#   'last_review': '2019-03-15',
#   'host_id': 34277274,
#   'column_19': 'Portugal',
#   'availability_365': 293,
#   'id': 6553932,
#   'column_20': 'Portugal, Lisbon, Ericeira',
#   'name': 'Apartamento acolhedor na ERICEIRA'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 3.63,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71588460817811, -9.137892146471675],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 169,
#   'column_10': 95,
#   'neighbourhood': 'Santa Maria Maior',
#   'last_review': '2019-04-15',
#   'host_id': 34592928,
#   'column_19': 'Portugal',
#   'availability_365': 249,
#   'id': 6610840,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'Stunning Castle Views, Garage & Lift In Downtown'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.13,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.734019968710356, -9.140099167439086],
#   'room_type': 'Private room',
#   'number_of_reviews': 6,
#   'column_10': 20,
#   'neighbourhood': 'Arroios',
#   'last_review': '2017-09-04',
#   'host_id': 34195436,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 6648661,
#   'column_20': 'Portugal, Lisbon, Arroios',
#   'name': 'Central Room in Lisbon'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.73,
#   'calculated_host_listings_count': 27,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.73169524801226, -9.133870760602756],
#   'room_type': 'Private room',
#   'number_of_reviews': 34,
#   'column_10': 13,
#   'neighbourhood': 'Arroios',
#   'last_review': '2018-09-14',
#   'host_id': 1208572,
#   'column_19': 'Portugal',
#   'availability_365': 264,
#   'id': 6721046,
#   'column_20': 'Portugal, Lisbon, Arroios',
#   'name': 'Andorinha Room'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 3.17,
#   'calculated_host_listings_count': 5,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.72367962638119, -9.153312768255896],
#   'room_type': 'Private room',
#   'number_of_reviews': 149,
#   'column_10': 35,
#   'neighbourhood': 'Santo Antnio',
#   'last_review': '2019-04-20',
#   'host_id': 34647309,
#   'column_19': 'Portugal',
#   'availability_365': 151,
#   'id': 6745986,
#   'column_20': 'Portugal, Lisbon, Santo Antnio',
#   'name': 'Central Room for Young Travelers4'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.17,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71738911882399, -9.161733186332208],
#   'room_type': 'Private room',
#   'number_of_reviews': 8,
#   'column_10': 50,
#   'neighbourhood': 'Campo de Ourique',
#   'last_review': '2015-10-30',
#   'host_id': 31239030,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 6757293,
#   'column_20': 'Portugal, Lisbon, Campo de Ourique',
#   'name': 'Double bedroom near the city center'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.26,
#   'calculated_host_listings_count': 33,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.69824470767308, -9.439235370779757],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 11,
#   'column_10': 132,
#   'neighbourhood': 'Cascais e Estoril',
#   'last_review': '2019-04-05',
#   'host_id': 25391913,
#   'column_19': 'Portugal',
#   'availability_365': 279,
#   'id': 6789431,
#   'column_20': 'Portugal, Lisbon, Cascais e Estoril',
#   'name': 'Oceanario 2 Bedroom Apartment w/ Sea View and Pool'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.24,
#   'calculated_host_listings_count': 68,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.72694072037514, -9.135149202195201],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 8,
#   'column_10': 250,
#   'neighbourhood': 'Arroios',
#   'last_review': '2018-07-21',
#   'host_id': 2372087,
#   'column_19': 'Portugal',
#   'availability_365': 297,
#   'id': 6839911,
#   'column_20': 'Portugal, Lisbon, Arroios',
#   'name': 'ALMIRANTE 1'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.29,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.71801910376107, -9.160988280818355],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 10,
#   'column_10': 60,
#   'neighbourhood': 'Campo de Ourique',
#   'last_review': '2017-08-09',
#   'host_id': 14759434,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 6861452,
#   'column_20': 'Portugal, Lisbon, Campo de Ourique',
#   'name': 'Estrela de São Joaquim'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.15,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 4,
#   'coordinates': [38.73454632786042, -9.139105597886648],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 7,
#   'column_10': 22,
#   'neighbourhood': 'Arroios',
#   'last_review': '2016-08-11',
#   'host_id': 28809298,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 6892532,
#   'column_20': 'Portugal, Lisbon, Arroios',
#   'name': 'Nice, cozy  T1 flat'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.08,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.715409634997705, -9.133961252088424],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 97,
#   'column_10': 45,
#   'neighbourhood': 'Santa Maria Maior',
#   'last_review': '2019-03-26',
#   'host_id': 36117900,
#   'column_19': 'Portugal',
#   'availability_365': 235,
#   'id': 6893054,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'Lisbon City Center'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.49,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 5,
#   'coordinates': [38.70962603778424, -9.415309012610047],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 22,
#   'column_10': 68,
#   'neighbourhood': 'Cascais e Estoril',
#   'last_review': '2018-09-14',
#   'host_id': 36636858,
#   'column_19': 'Portugal',
#   'availability_365': 81,
#   'id': 6987884,
#   'column_20': 'Portugal, Lisbon, Cascais e Estoril',
#   'name': 'Casinha com jardim'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.2,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 4,
#   'coordinates': [39.272952480499754, -9.23545925889285],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 9,
#   'column_10': 89,
#   'neighbourhood': 'So Bartolomeu dos Galegos e Moledo',
#   'last_review': '2018-08-08',
#   'host_id': 36795920,
#   'column_19': 'Portugal',
#   'availability_365': 146,
#   'id': 7019809,
#   'column_20': 'Portugal, Lisbon, So Bartolomeu dos Galegos e Moledo',
#   'name': '"L\'Atelier du Peintre"'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.18,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.72530352386295, -9.16568536804404],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 8,
#   'column_10': 60,
#   'neighbourhood': 'Campolide',
#   'last_review': '2016-08-27',
#   'host_id': 3183210,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 7021012,
#   'column_20': 'Portugal, Lisbon, Campolide',
#   'name': 'Gorgeous attic with amazing view'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 4.49,
#   'calculated_host_listings_count': 19,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.713462794778955, -9.131346146144278],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 176,
#   'column_10': 40,
#   'neighbourhood': 'Santa Maria Maior',
#   'last_review': '2019-04-17',
#   'host_id': 5588401,
#   'column_19': 'Portugal',
#   'availability_365': 221,
#   'id': 7079897,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'Cosy Studio in the Castle area'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 2,
#   'minimum_nights': 3,
#   'coordinates': [39.10350835182846, -9.33981318559401],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 30,
#   'neighbourhood': 'Silveira',
#   'host_id': 37309506,
#   'column_19': 'Portugal',
#   'availability_365': 178,
#   'id': 7122749,
#   'column_20': 'Portugal, Lisbon, Silveira',
#   'name': 'Casa Giovanni'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.34,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 7,
#   'coordinates': [38.82034193592283, -9.438551305016585],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 11,
#   'column_10': 150,
#   'neighbourhood': 'S.Maria, S.Miguel, S.Martinho, S.Pedro Penaferrim',
#   'last_review': '2018-08-26',
#   'host_id': 36411687,
#   'column_19': 'Portugal',
#   'availability_365': 90,
#   'id': 7142562,
#   'column_20': 'Portugal, Lisbon, S.Maria, S.Miguel, S.Martinho, S.Pedro Penaferrim',
#   'name': 'Colares / Galadriel Villa'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 5.62,
#   'calculated_host_listings_count': 11,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.711025105682026, -9.144428746910664],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 257,
#   'column_10': 49,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-03-31',
#   'host_id': 14291065,
#   'column_19': 'Portugal',
#   'availability_365': 283,
#   'id': 7302706,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Amazing rooftop view - Bairro Alto'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.55,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.70265055813432, -9.430544595231336],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 25,
#   'column_10': 80,
#   'neighbourhood': 'Cascais e Estoril',
#   'last_review': '2018-09-17',
#   'host_id': 19312963,
#   'column_19': 'Portugal',
#   'availability_365': 73,
#   'id': 7329439,
#   'column_20': 'Portugal, Lisbon, Cascais e Estoril',
#   'name': 'cascais apartment'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 1.48,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 5,
#   'coordinates': [38.714738599369724, -9.136531991147294],
#   'room_type': 'Private room',
#   'number_of_reviews': 67,
#   'column_10': 30,
#   'neighbourhood': 'Santa Maria Maior',
#   'last_review': '2018-11-08',
#   'host_id': 4283351,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 7334193,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'Cozy Room @ old city heart ❤️'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.61,
#   'calculated_host_listings_count': 55,
#   'city': 'Lisbon',
#   'minimum_nights': 1,
#   'coordinates': [38.71989908333498, -9.133334985157983],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 118,
#   'column_10': 100,
#   'neighbourhood': 'So Vicente',
#   'last_review': '2019-03-25',
#   'host_id': 1549585,
#   'column_19': 'Portugal',
#   'availability_365': 277,
#   'id': 7380350,
#   'column_20': 'Portugal, Lisbon, So Vicente',
#   'name': 'ShortStayFlat - Spacious & Design Duplex'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 1.21,
#   'calculated_host_listings_count': 2,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.960757163173824, -9.417281316942296],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 54,
#   'column_10': 79,
#   'neighbourhood': 'Ericeira',
#   'last_review': '2019-04-16',
#   'host_id': 38774003,
#   'column_19': 'Portugal',
#   'availability_365': 304,
#   'id': 7400260,
#   'column_20': 'Portugal, Lisbon, Ericeira',
#   'name': 'Ericeira Sunset House'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 5.23,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71772542776206, -9.13966791086446],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 140,
#   'column_10': 85,
#   'neighbourhood': 'Arroios',
#   'last_review': '2019-04-06',
#   'host_id': 4191034,
#   'column_19': 'Portugal',
#   'availability_365': 212,
#   'id': 7438144,
#   'column_20': 'Portugal, Lisbon, Arroios',
#   'name': "Do Adro's backyard apartment"},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 2.82,
#   'calculated_host_listings_count': 4,
#   'city': 'Lisbon',
#   'minimum_nights': 3,
#   'coordinates': [38.7068007000865, -9.171070012374702],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 126,
#   'column_10': 66,
#   'neighbourhood': 'Estrela',
#   'last_review': '2018-10-06',
#   'host_id': 557442,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 7453348,
#   'column_20': 'Portugal, Lisbon, Estrela',
#   'name': 'Between Beach+Historical Monuments'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.34,
#   'calculated_host_listings_count': 4,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.700400588124715, -9.170612788707144],
#   'room_type': 'Private room',
#   'number_of_reviews': 9,
#   'column_10': 75,
#   'neighbourhood': 'Estrela',
#   'last_review': '2018-08-13',
#   'host_id': 37046559,
#   'column_19': 'Portugal',
#   'availability_365': 362,
#   'id': 7467021,
#   'column_20': 'Portugal, Lisbon, Estrela',
#   'name': 'The One Experience- Starboard Suite'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.33,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.70821257277977, -9.129424250042224],
#   'room_type': 'Private room',
#   'number_of_reviews': 15,
#   'column_10': 20,
#   'neighbourhood': 'Santa Maria Maior',
#   'last_review': '2018-03-28',
#   'host_id': 39323599,
#   'column_19': 'Portugal',
#   'availability_365': 235,
#   'id': 7506332,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'B&B - Room with an amazing river view'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 3.09,
#   'calculated_host_listings_count': 4,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.7257038882291, -9.137929164905728],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 138,
#   'column_10': 48,
#   'neighbourhood': 'Arroios',
#   'last_review': '2019-04-11',
#   'host_id': 39868226,
#   'column_19': 'Portugal',
#   'availability_365': 324,
#   'id': 7602473,
#   'column_20': 'Portugal, Lisbon, Arroios',
# ...
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.41,
#   'calculated_host_listings_count': 4,
#   'city': 'Hawaii',
#   'minimum_nights': 2,
#   'coordinates': [19.500661594019903, -155.91678344674946],
#   'room_type': 'Private room',
#   'number_of_reviews': 1,
#   'column_10': 137,
#   'neighbourhood': 'South Kona',
#   'last_review': '2019-02-19',
#   'host_id': 48121704,
#   'column_19': 'United states',
#   'availability_365': 269,
#   'id': 14616989,
#   'column_20': 'United states, Hawaii, South Kona',
#   'name': 'Mermaid Dreams Bed & Breakfast -- Seahorse Room'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.32,
#   'calculated_host_listings_count': 212,
#   'city': 'Hawaii',
#   'minimum_nights': 1,
#   'coordinates': [19.62939271310789, -155.98921185207692],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 10,
#   'column_10': 295,
#   'neighbourhood': 'North Kona',
#   'last_review': '2018-12-23',
#   'host_id': 18476866,
#   'column_19': 'United states',
#   'availability_365': 257,
#   'id': 14688241,
#   'column_20': 'United states, Hawaii, North Kona',
#   'name': 'Kona Reef A6 Oceanfront AC Walk to Town'},
#  {'updated_date': '2019-05-03',
#   'city': 'Hawaii',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 7,
#   'coordinates': [20.9916632988086, -156.6676813593341],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 285,
#   'neighbourhood': 'Lahaina',
#   'host_id': 42228150,
#   'column_19': 'United states',
#   'availability_365': 255,
#   'id': 14758891,
#   'column_20': 'United states, Hawaii, Lahaina',
#   'name': 'FANTASTIC VIEW, NAPILI SHORES H263 OCEAN FRONT'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 2.32,
#   'calculated_host_listings_count': 4,
#   'city': 'Hawaii',
#   'minimum_nights': 2,
#   'coordinates': [21.27545511494017, -157.80692717648705],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 75,
#   'column_10': 249,
#   'neighbourhood': 'Primary Urban Center',
#   'last_review': '2019-04-27',
#   'host_id': 32318851,
#   'column_19': 'United states',
#   'availability_365': 100,
#   'id': 14776542,
#   'column_20': 'United states, Hawaii, Primary Urban Center',
#   'name': "BETTY'S BRAND NEW 2-BED W/ PARKING, NEAR WAIKIKI"},
#  {'updated_date': '2019-05-03',
#   'city': 'Hawaii',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 7,
#   'coordinates': [20.92533275030851, -156.69082755967278],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 500,
#   'neighbourhood': 'Lahaina',
#   'host_id': 92331947,
#   'column_19': 'United states',
#   'availability_365': 46,
#   'id': 14787304,
#   'column_20': 'United states, Hawaii, Lahaina',
#   'name': 'Maui Oceanview Luxury Spacious 2 Bed/2 Bath Condo'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 2.35,
#   'calculated_host_listings_count': 1,
#   'city': 'Hawaii',
#   'minimum_nights': 1,
#   'coordinates': [21.55473949174235, -157.8526267078041],
#   'room_type': 'Private room',
#   'number_of_reviews': 74,
#   'column_10': 109,
#   'neighbourhood': 'Koolauloa',
#   'last_review': '2019-04-06',
#   'host_id': 92349163,
#   'column_19': 'United states',
#   'availability_365': 357,
#   'id': 14840727,
#   'column_20': 'United states, Hawaii, Koolauloa',
#   'name': 'Enjoy Ocean View from your Tropical Paradise room!'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.31,
#   'calculated_host_listings_count': 1,
#   'city': 'Hawaii',
#   'minimum_nights': 7,
#   'coordinates': [20.913829001234493, -156.69231325924022],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 1,
#   'column_10': 970,
#   'neighbourhood': 'Lahaina',
#   'last_review': '2019-01-26',
#   'host_id': 95458940,
#   'column_19': 'United states',
#   'availability_365': 28,
#   'id': 15084945,
#   'column_20': 'United states, Hawaii, Lahaina',
#   'name': "Maui Ka'anapali, private club, luxury ocean-front"},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 1.47,
#   'calculated_host_listings_count': 4,
#   'city': 'Hawaii',
#   'minimum_nights': 3,
#   'coordinates': [19.435692561817934, -155.2427306117237],
#   'room_type': 'Private room',
#   'number_of_reviews': 46,
#   'column_10': 98,
#   'neighbourhood': 'Puna',
#   'last_review': '2019-01-20',
#   'host_id': 95609457,
#   'column_19': 'United states',
#   'availability_365': 75,
#   'id': 15099749,
#   'column_20': 'United states, Hawaii, Puna',
#   'name': 'Quiet Hawaiian Forest Cabin'},
#  {'updated_date': '2019-05-03',
#   'city': 'Hawaii',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [22.062491038693956, -159.32017540076308],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 355,
#   'neighbourhood': 'Kapaa-Wailua',
#   'host_id': 16913110,
#   'column_19': 'United states',
#   'availability_365': 278,
#   'id': 15146984,
#   'column_20': 'United states, Hawaii, Kapaa-Wailua',
#   'name': 'Kauai 1 Bedroom Condo'},
#  {'updated_date': '2019-05-03',
#   'city': 'Hawaii',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 5,
#   'coordinates': [20.721573534422337, -156.4470353674976],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 240,
#   'neighbourhood': 'Kihei-Makena',
#   'host_id': 54796115,
#   'column_19': 'United states',
#   'availability_365': 253,
#   'id': 15162993,
#   'column_20': 'United states, Hawaii, Kihei-Makena',
#   'name': 'Panoramic OceanView Apartment,  Upscale'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.73,
#   'calculated_host_listings_count': 21,
#   'city': 'Hawaii',
#   'minimum_nights': 3,
#   'coordinates': [21.276062036520262, -157.82174170333417],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 22,
#   'column_10': 180,
#   'neighbourhood': 'Primary Urban Center',
#   'last_review': '2019-02-25',
#   'host_id': 26591491,
#   'column_19': 'United states',
#   'availability_365': 338,
#   'id': 15202618,
#   'column_20': 'United states, Hawaii, Primary Urban Center',
#   'name': 'Waikiki Skytower (Modern 1 bedroom)'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.44,
#   'calculated_host_listings_count': 28,
#   'city': 'Hawaii',
#   'minimum_nights': 1,
#   'coordinates': [21.280143829288473, -157.8249893178242],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 12,
#   'column_10': 131,
#   'neighbourhood': 'Primary Urban Center',
#   'last_review': '2019-04-15',
#   'host_id': 40240788,
#   'column_19': 'United states',
#   'availability_365': 281,
#   'id': 15208211,
#   'column_20': 'United states, Hawaii, Primary Urban Center',
#   'name': 'Studio condo with views of Diamond Head, private lanai, shared pool/hot tub!'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.48,
#   'calculated_host_listings_count': 1,
#   'city': 'Hawaii',
#   'minimum_nights': 5,
#   'coordinates': [19.642164847842306, -155.9933332131811],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 8,
#   'column_10': 115,
#   'neighbourhood': 'North Kona',
#   'last_review': '2019-03-29',
#   'host_id': 21808767,
#   'column_19': 'United states',
#   'availability_365': 299,
#   'id': 15232439,
#   'column_20': 'United states, Hawaii, North Kona',
#   'name': 'Gorgeous Remodeled Downtown Kona Condo! NEW!'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.18,
#   'calculated_host_listings_count': 108,
#   'city': 'Hawaii',
#   'minimum_nights': 5,
#   'coordinates': [20.94377124553496, -156.69136974948634],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 3,
#   'column_10': 795,
#   'neighbourhood': 'Lahaina',
#   'last_review': '2018-10-19',
#   'host_id': 39073224,
#   'column_19': 'United states',
#   'availability_365': 233,
#   'id': 15235203,
#   'column_20': 'United states, Hawaii, Lahaina',
#   'name': 'Maui Resort Rentals: Honua Kai Hokulani 618'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.24,
#   'calculated_host_listings_count': 212,
#   'city': 'Hawaii',
#   'minimum_nights': 1,
#   'coordinates': [19.62073376963632, -155.98574321764715],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 6,
#   'column_10': 257,
#   'neighbourhood': 'North Kona',
#   'last_review': '2019-03-25',
#   'host_id': 18476866,
#   'column_19': 'United states',
#   'availability_365': 259,
#   'id': 15236676,
#   'column_20': 'United states, Hawaii, North Kona',
#   'name': 'Alii Villas #128 2BD/2BA Ocean View'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.04,
#   'calculated_host_listings_count': 2,
#   'city': 'Hawaii',
#   'minimum_nights': 30,
#   'coordinates': [21.2823459664176, -157.82696149887445],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 1,
#   'column_10': 49,
#   'neighbourhood': 'Primary Urban Center',
#   'last_review': '2017-02-06',
#   'host_id': 64469977,
#   'column_19': 'United states',
#   'availability_365': 2,
#   'id': 15278282,
#   'column_20': 'United states, Hawaii, Primary Urban Center',
#   'name': 'Great nicely studio in Wakiki'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.18,
#   'calculated_host_listings_count': 119,
#   'city': 'Hawaii',
#   'minimum_nights': 3,
#   'coordinates': [21.87676975991982, -159.44783222931167],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 2,
#   'column_10': 263,
#   'neighbourhood': 'Koloa-Poipu',
#   'last_review': '2018-08-04',
#   'host_id': 97006413,
#   'column_19': 'United states',
#   'availability_365': 181,
#   'id': 15286440,
#   'column_20': 'United states, Hawaii, Koloa-Poipu',
#   'name': 'Poipu Panoramic Ocean View A/C Bedrooms *Kahala 614*'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.08,
#   'calculated_host_listings_count': 119,
#   'city': 'Hawaii',
#   'minimum_nights': 3,
#   'coordinates': [21.874552494531212, -159.44989668268727],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 2,
#   'column_10': 206,
#   'neighbourhood': 'Koloa-Poipu',
#   'last_review': '2018-05-06',
#   'host_id': 97006413,
#   'column_19': 'United states',
#   'availability_365': 284,
#   'id': 15286506,
#   'column_20': 'United states, Hawaii, Koloa-Poipu',
#   'name': 'Poipu Ground Floor w/Perfect Garden View A/C Living Room*Manualoha 1103*'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.1,
#   'calculated_host_listings_count': 119,
#   'city': 'Hawaii',
#   'minimum_nights': 3,
#   'coordinates': [21.874569753851745, -159.44598344415346],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 2,
#   'column_10': 320,
#   'neighbourhood': 'Koloa-Poipu',
#   'last_review': '2019-04-11',
#   'host_id': 97006413,
#   'column_19': 'United states',
#   'availability_365': 256,
#   'id': 15286573,
#   'column_20': 'United states, Hawaii, Koloa-Poipu',
#   'name': 'Poipu Peaceful Garden Retreat Pool/Jacuzzi AC in the Master Suite & Loft *Regency 321*'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.2,
#   'calculated_host_listings_count': 119,
#   'city': 'Hawaii',
#   'minimum_nights': 3,
#   'coordinates': [21.876871248167, -159.44717678611846],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 2,
#   'column_10': 286,
#   'neighbourhood': 'Koloa-Poipu',
#   'last_review': '2018-08-03',
#   'host_id': 97006413,
#   'column_19': 'United states',
#   'availability_365': 274,
#   'id': 15286587,
#   'column_20': 'United states, Hawaii, Koloa-Poipu',
#   'name': 'Poipu Spacious Bright Family Condo in Poipu Kai *Regency 520*'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 2.19,
#   'calculated_host_listings_count': 1,
#   'city': 'Hawaii',
#   'minimum_nights': 5,
#   'coordinates': [21.31019215248727, -157.6832694911966],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 58,
#   'column_10': 100,
#   'neighbourhood': 'East Honolulu',
#   'last_review': '2019-03-27',
#   'host_id': 67295903,
#   'column_19': 'United states',
#   'availability_365': 293,
#   'id': 15347210,
#   'column_20': 'United states, Hawaii, East Honolulu',
#   'name': "Hale Ho'o Kipa"},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.81,
#   'calculated_host_listings_count': 2,
#   'city': 'Hawaii',
#   'minimum_nights': 7,
#   'coordinates': [20.71431143258302, -156.44573755220037],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 25,
#   'column_10': 185,
#   'neighbourhood': 'Kihei-Makena',
#   'last_review': '2019-03-12',
#   'host_id': 61821986,
#   'column_19': 'United states',
#   'availability_365': 233,
#   'id': 15358684,
#   'column_20': 'United states, Hawaii, Kihei-Makena',
#   'name': 'Gorgeous 2 bedroom 2 bath spacious condo 9-402'},
#  {'updated_date': '2019-05-03',
#   'city': 'Hawaii',
#   'calculated_host_listings_count': 53,
#   'minimum_nights': 4,
#   'coordinates': [20.00713504455208, -155.80802121154915],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 575,
#   'neighbourhood': 'South Kohala',
#   'host_id': 96255708,
#   'column_19': 'United states',
#   'availability_365': 247,
#   'id': 15409191,
#   'column_20': 'United states, Hawaii, South Kohala',
#   'name': '❤️PiH❤️ Beautiful Ocean Villa ★ Gorgeous Views'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.07,
#   'calculated_host_listings_count': 1,
#   'city': 'Hawaii',
#   'minimum_nights': 7,
#   'coordinates': [20.971204091867673, -156.6769286756077],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 2,
#   'column_10': 400,
#   'neighbourhood': 'Lahaina',
#   'last_review': '2018-12-28',
#   'host_id': 12735119,
#   'column_19': 'United states',
#   'availability_365': 119,
#   'id': 15451995,
#   'column_20': 'United states, Hawaii, Lahaina',
#   'name': 'Your Dream Vacation in Maui- for the holidays'},
#  {'updated_date': '2019-05-03',
#   'city': 'Hawaii',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 30,
#   'coordinates': [21.285688601770286, -157.83491421598353],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 199,
#   'neighbourhood': 'Primary Urban Center',
#   'host_id': 17939795,
#   'column_19': 'United states',
#   'availability_365': 363,
#   'id': 15468300,
#   'column_20': 'United states, Hawaii, Primary Urban Center',
#   'name': 'Great Views - Great Vacation Rental 5 min to Beach'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.47,
#   'calculated_host_listings_count': 82,
#   'city': 'Hawaii',
#   'minimum_nights': 5,
#   'coordinates': [22.221131347251017, -159.4873729072357],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 14,
#   'column_10': 431,
#   'neighbourhood': 'North Shore Kauai',
#   'last_review': '2018-10-11',
#   'host_id': 47208806,
#   'column_19': 'United states',
#   'availability_365': 236,
#   'id': 15482342,
#   'column_20': 'United states, Hawaii, North Shore Kauai',
#   'name': 'AC, Hot Tub, BBQ, & Shared Pool'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 0.71,
#   'calculated_host_listings_count': 94,
#   'city': 'Hawaii',
#   'minimum_nights': 2,
#   'coordinates': [21.26157051506708, -157.8205586893975],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 21,
#   'column_10': 345,
#   'neighbourhood': 'Primary Urban Center',
#   'last_review': '2019-03-02',
#   'host_id': 43793840,
#   'column_19': 'United states',
#   'availability_365': 238,
#   'id': 15499008,
#   'column_20': 'United states, Hawaii, Primary Urban Center',
#   'name': 'Well Appointed Penthouse Private Ocean Lanai 1401'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 3.18,
#   'calculated_host_listings_count': 1,
#   'city': 'Hawaii',
#   'minimum_nights': 1,
#   'coordinates': [19.712502836305408, -155.0674001795268],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 91,
#   'column_10': 180,
#   'neighbourhood': 'South Hilo',
#   'last_review': '2019-04-28',
#   'host_id': 21267026,
#   'column_19': 'United states',
#   'availability_365': 321,
#   'id': 15605384,
#   'column_20': 'United states, Hawaii, South Hilo',
#   'name': 'House w/Yard in Hilo, close to Everything, 3bd2bth'},
#  {'updated_date': '2019-05-03',
#   'reviews_per_month': 1.21,
#   'calculated_host_listings_count': 16,
#   'city': 'Hawaii',
#   'minimum_nights': 1,
#   'coordinates': [21.393282382366266, -157.73465857685534],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 37,
#   'column_10': 119,
#   'neighbourhood': 'Koolaupoko',
#   'last_review': '2019-04-28',
#   'host_id': 26157559,
#   'column_19': 'United states',
#   'availability_365': 266,
#   'id': 15635430,
#   'column_20': 'United states, Hawaii, Koolaupoko',
#   'name': "D&D's B&B- sweet island style Studio"}]

# %%
results_df = pd.DataFrame(results)
results_df.head()
# Out:
#    availability_365  calculated_host_listings_count    city  column_10  \
# 0               292                               7  Lisbon        125
# 1                 0                               1  Lisbon        500
# 2                 0                               1  Lisbon        650
# 3                 0                               1  Lisbon        500
# 4               277                               3  Lisbon         37
#
#   column_19                                          column_20  \
# 0  Portugal                   Portugal, Lisbon, Avenidas Novas
# 1  Portugal                         Portugal, Lisbon, Alcntara
# 2  Portugal           Portugal, Lisbon, So Domingos de Benfica
# 3  Portugal  Portugal, Lisbon, Algs, Linda-a-Velha e Cruz Q...
# 4  Portugal                      Portugal, Lisbon, Misericrdia
#
#                                coordinates   host_id       id last_review  \
# 0  [38.74584282796673, -9.152359763007405]  15282851  2998105  2019-04-17
# 1  [38.70213919994125, -9.177363170810427]  15307946  3003712         NaN
# 2  [38.74499852902329, -9.168202490560926]  15330291  3008031         NaN
# 3  [38.70144477298908, -9.240587547103432]  15415294  3025693         NaN
# 4  [38.71109888002856, -9.148347820132365]  15580486  3063405  2019-04-19
#
#    minimum_nights                                 name  \
# 0               2          Exciting Lisbon Entrecampos
# 1               1  Fantastic Apartment with deck 120m2
# 2               1           Champions League apartment
# 3               1                      Quarto em Algés
# 4               2  Camões Lounge Apartment w/Courtyard
#
#                                  neighbourhood  number_of_reviews  \
# 0                               Avenidas Novas                297
# 1                                     Alcntara                  0
# 2                       So Domingos de Benfica                  0
# 3  Algs, Linda-a-Velha e Cruz Quebrada-Dafundo                  0
# 4                                  Misericrdia                299
#
#    reviews_per_month        room_type updated_date
# 0               4.97  Entire home/apt   2019-04-22
# 1                NaN     Private room   2019-04-22
# 2                NaN  Entire home/apt   2019-04-22
# 3                NaN     Private room   2019-04-22
# 4               5.02  Entire home/apt   2019-04-22

# %%
cleanData = results_df[[ 'column_10','id', 'coordinates', 'room_type', "city", 'column_19']]
cleanData.head()
# Out:
#    column_10       id                              coordinates  \
# 0        125  2998105  [38.74584282796673, -9.152359763007405]
# 1        500  3003712  [38.70213919994125, -9.177363170810427]
# 2        650  3008031  [38.74499852902329, -9.168202490560926]
# 3        500  3025693  [38.70144477298908, -9.240587547103432]
# 4         37  3063405  [38.71109888002856, -9.148347820132365]
#
#          room_type    city column_19
# 0  Entire home/apt  Lisbon  Portugal
# 1     Private room  Lisbon  Portugal
# 2  Entire home/apt  Lisbon  Portugal
# 3     Private room  Lisbon  Portugal
# 4  Entire home/apt  Lisbon  Portugal

# %%
cleanData = cleanData.rename(index=str, columns={"column_10":"Price",
                                                 "id":"Room_Id", 
                                                 "coordinates":"Coordinates",
                                                 "column_19":"Country", 
                                                 "room_type":"Room_Type",
                                                 "city":"City"})

cleanData.head()
# Out:
#    Price  Room_Id                              Coordinates        Room_Type  \
# 0    125  2998105  [38.74584282796673, -9.152359763007405]  Entire home/apt
# 1    500  3003712  [38.70213919994125, -9.177363170810427]     Private room
# 2    650  3008031  [38.74499852902329, -9.168202490560926]  Entire home/apt
# 3    500  3025693  [38.70144477298908, -9.240587547103432]     Private room
# 4     37  3063405  [38.71109888002856, -9.148347820132365]  Entire home/apt
#
#      City   Country
# 0  Lisbon  Portugal
# 1  Lisbon  Portugal
# 2  Lisbon  Portugal
# 3  Lisbon  Portugal
# 4  Lisbon  Portugal

# %%
# Create two lists for the loop results to be placed
lat = []
lon = []

# For each row in a varible,
for row in cleanData['Coordinates']:
   # Try to,
   try:
       # Split the row by comma and append
       # everything before the comma to lat
       lat.append(row[0])
       # Split the row by comma and append
       # everything after the comma to lon
       lon.append(row[1])
   # But if you get an error
   except:
       # append a missing value to lat
       lat.append(np.NaN)
       # append a missing value to lon
       lon.append(np.NaN)

# Create two new columns from lat and lon
cleanData['Latitude'] = lat
cleanData['Longitude'] = lon

# %%
cleanData = cleanData.drop(columns=["Coordinates"])
cleanData.head()
# Out:
#    Price  Room_Id        Room_Type    City   Country   Latitude  Longitude
# 0    125  2998105  Entire home/apt  Lisbon  Portugal  38.745843  -9.152360
# 1    500  3003712     Private room  Lisbon  Portugal  38.702139  -9.177363
# 2    650  3008031  Entire home/apt  Lisbon  Portugal  38.744999  -9.168202
# 3    500  3025693     Private room  Lisbon  Portugal  38.701445  -9.240588
# 4     37  3063405  Entire home/apt  Lisbon  Portugal  38.711099  -9.148348

# %%
cleanData["Selection"] = cleanData["City"]+", "+cleanData["Country"]
cleanData.head()
# Out:
#    Price  Room_Id        Room_Type    City   Country   Latitude  Longitude  \
# 0    125  2998105  Entire home/apt  Lisbon  Portugal  38.745843  -9.152360
# 1    500  3003712     Private room  Lisbon  Portugal  38.702139  -9.177363
# 2    650  3008031  Entire home/apt  Lisbon  Portugal  38.744999  -9.168202
# 3    500  3025693     Private room  Lisbon  Portugal  38.701445  -9.240588
# 4     37  3063405  Entire home/apt  Lisbon  Portugal  38.711099  -9.148348
#
#           Selection
# 0  Lisbon, Portugal
# 1  Lisbon, Portugal
# 2  Lisbon, Portugal
# 3  Lisbon, Portugal
# 4  Lisbon, Portugal

# %%
conn_str = "root:***password***@localhost/airbnb_data"
engine = create_engine(f'mysql://{conn_str}')

#check for tables in database
#engine.table_names()

#enter data into database
***df***.to_sql(name="airbnb_data_tbl", con=engine, if_exists="append",index=False)
