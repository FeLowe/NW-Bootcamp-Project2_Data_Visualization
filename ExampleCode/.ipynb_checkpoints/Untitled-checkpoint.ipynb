# %%
import requests
import json
from pprint import pprint
import numpy as np
import pandas as pd
import os
import datetime as dt

import sqlalchemy
from sqlalchemy import create_engine, func, inspect
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float, Date
from opencage.geocoder import OpenCageGeocode # used to get long and lat of given city name
from math import radians, sin, cos, asin, sqrt # used to calculate distance of room and city longs and lats

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session


from flask import Flask, jsonify

# %%
results = requests.get('https://public.opendatasoft.com/api/records/1.0/download/?dataset=air-bnb-listings&rows=10&format=json').json()

# %%
pprint(results)
# Out:
# [{'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 292,
#              'calculated_host_listings_count': 7,
#              'city': 'Lisbon',
#              'column_10': 125,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Avenidas Novas',
#              'coordinates': [38.74584282796673, -9.152359763007405],
#              'host_id': 15282851,
#              'id': 2998105,
#              'last_review': '2019-04-17',
#              'minimum_nights': 2,
#              'name': 'Exciting Lisbon Entrecampos',
#              'neighbourhood': 'Avenidas Novas',
#              'number_of_reviews': 297,
#              'reviews_per_month': 4.97,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.152359763007405, 38.74584282796673],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '64d5c2753e54fa16731ea8f7cf03163b079eb035'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 500,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Alcntara',
#              'coordinates': [38.70213919994125, -9.177363170810427],
#              'host_id': 15307946,
#              'id': 3003712,
#              'minimum_nights': 1,
#              'name': 'Fantastic Apartment with deck 120m2',
#              'neighbourhood': 'Alcntara',
#              'number_of_reviews': 0,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.177363170810427, 38.70213919994125],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '33e33624e78acf6a439ea268704a78aaf3aaacdc'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 650,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, So Domingos de Benfica',
#              'coordinates': [38.74499852902329, -9.168202490560926],
#              'host_id': 15330291,
#              'id': 3008031,
#              'minimum_nights': 1,
#              'name': 'Champions League apartment',
#              'neighbourhood': 'So Domingos de Benfica',
#              'number_of_reviews': 0,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.168202490560926, 38.74499852902329],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '1fca366b305dfa6b07cfb57f4551594c3bb1488c'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 500,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Algs, Linda-a-Velha e Cruz '
#                           'Quebrada-Dafundo',
#              'coordinates': [38.70144477298908, -9.240587547103432],
#              'host_id': 15415294,
#              'id': 3025693,
#              'minimum_nights': 1,
#              'name': 'Quarto em Algés',
#              'neighbourhood': 'Algs, Linda-a-Velha e Cruz Quebrada-Dafundo',
#              'number_of_reviews': 0,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.240587547103432, 38.70144477298908],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'ddd57fd1c1132e1692307668968cc1eb9618d514'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 277,
#              'calculated_host_listings_count': 3,
#              'city': 'Lisbon',
#              'column_10': 37,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Misericrdia',
#              'coordinates': [38.71109888002856, -9.148347820132365],
#              'host_id': 15580486,
#              'id': 3063405,
#              'last_review': '2019-04-19',
#              'minimum_nights': 2,
#              'name': 'Camões Lounge Apartment w/Courtyard',
#              'neighbourhood': 'Misericrdia',
#              'number_of_reviews': 299,
#              'reviews_per_month': 5.02,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.148347820132365, 38.71109888002856],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'f73e54b5efaab5e7c5afe52e126316f4fa499d45'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 1200,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#              'coordinates': [38.70824853381608, -9.140954694999623],
#              'host_id': 15733441,
#              'id': 3096570,
#              'minimum_nights': 1,
#              'name': 'Alugo de 24 a 25 Champions League',
#              'neighbourhood': 'Santa Maria Maior',
#              'number_of_reviews': 0,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.140954694999623, 38.70824853381608],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': '056571e251f584f1efcb2e912fe9da115dcd6c69'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 500,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Venteira',
#              'coordinates': [38.751007598903335, -9.232284530702461],
#              'host_id': 15826178,
#              'id': 3114625,
#              'minimum_nights': 1,
#              'name': 'Quarto/Final UEFA CUP Lisboa',
#              'neighbourhood': 'Venteira',
#              'number_of_reviews': 0,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.232284530702461, 38.751007598903335],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'd62d3c2ff682e132f4167fc07a5515d3146f211f'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 2,
#              'city': 'Lisbon',
#              'column_10': 800,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Carnide',
#              'coordinates': [38.75894252695615, -9.193017167119498],
#              'host_id': 15830223,
#              'id': 3115589,
#              'minimum_nights': 1,
#              'name': 'Room for Champions League',
#              'neighbourhood': 'Carnide',
#              'number_of_reviews': 0,
#              'room_type': 'Private room',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.193017167119498, 38.75894252695615],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'e2dc484b13a8e268b2d0c22ae87667391db8021d'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 0,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 1000,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, guas Livres',
#              'coordinates': [38.746816666725785, -9.213504769043555],
#              'host_id': 15871370,
#              'id': 3124693,
#              'minimum_nights': 1,
#              'name': "Lisbon -Champions Final 10''Stadium",
#              'neighbourhood': 'guas Livres',
#              'number_of_reviews': 0,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.213504769043555, 38.746816666725785],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'a0bead43c0b3ad84417dcc29c8a45c0872fa0c70'},
#  {'datasetid': 'air-bnb-listings',
#   'fields': {'availability_365': 22,
#              'calculated_host_listings_count': 1,
#              'city': 'Lisbon',
#              'column_10': 320,
#              'column_19': 'Portugal',
#              'column_20': 'Portugal, Lisbon, Almargem do Bispo, Pro Pinheiro e '
#                           'Montelavar',
#              'coordinates': [38.82631965777253, -9.275936216712273],
#              'host_id': 15916831,
#              'id': 3134497,
#              'last_review': '2018-10-07',
#              'minimum_nights': 2,
#              'name': 'Villa cerrado das fontainhas',
#              'neighbourhood': 'Almargem do Bispo, Pro Pinheiro e Montelavar',
#              'number_of_reviews': 17,
#              'reviews_per_month': 0.72,
#              'room_type': 'Entire home/apt',
#              'updated_date': '2019-04-22'},
#   'geometry': {'coordinates': [-9.275936216712273, 38.82631965777253],
#                'type': 'Point'},
#   'record_timestamp': '2019-06-07T06:01:00Z',
#   'recordid': 'eccd530bfb087ff15ad61927b4f28a446ac22cd9'}]

# %%
results = [r["fields"] for r in results]
results
# Out:
# [{'updated_date': '2019-04-22',
#   'reviews_per_month': 4.97,
#   'calculated_host_listings_count': 7,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.74584282796673, -9.152359763007405],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 297,
#   'column_10': 125,
#   'neighbourhood': 'Avenidas Novas',
#   'last_review': '2019-04-17',
#   'host_id': 15282851,
#   'column_19': 'Portugal',
#   'availability_365': 292,
#   'id': 2998105,
#   'column_20': 'Portugal, Lisbon, Avenidas Novas',
#   'name': 'Exciting Lisbon Entrecampos'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.70213919994125, -9.177363170810427],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 500,
#   'neighbourhood': 'Alcntara',
#   'host_id': 15307946,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3003712,
#   'column_20': 'Portugal, Lisbon, Alcntara',
#   'name': 'Fantastic Apartment with deck 120m2'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.74499852902329, -9.168202490560926],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 650,
#   'neighbourhood': 'So Domingos de Benfica',
#   'host_id': 15330291,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3008031,
#   'column_20': 'Portugal, Lisbon, So Domingos de Benfica',
#   'name': 'Champions League apartment'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.70144477298908, -9.240587547103432],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 500,
#   'neighbourhood': 'Algs, Linda-a-Velha e Cruz Quebrada-Dafundo',
#   'host_id': 15415294,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3025693,
#   'column_20': 'Portugal, Lisbon, Algs, Linda-a-Velha e Cruz Quebrada-Dafundo',
#   'name': 'Quarto em Algés'},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 5.02,
#   'calculated_host_listings_count': 3,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.71109888002856, -9.148347820132365],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 299,
#   'column_10': 37,
#   'neighbourhood': 'Misericrdia',
#   'last_review': '2019-04-19',
#   'host_id': 15580486,
#   'column_19': 'Portugal',
#   'availability_365': 277,
#   'id': 3063405,
#   'column_20': 'Portugal, Lisbon, Misericrdia',
#   'name': 'Camões Lounge Apartment w/Courtyard'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.70824853381608, -9.140954694999623],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 1200,
#   'neighbourhood': 'Santa Maria Maior',
#   'host_id': 15733441,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3096570,
#   'column_20': 'Portugal, Lisbon, Santa Maria Maior',
#   'name': 'Alugo de 24 a 25 Champions League'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.751007598903335, -9.232284530702461],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 500,
#   'neighbourhood': 'Venteira',
#   'host_id': 15826178,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3114625,
#   'column_20': 'Portugal, Lisbon, Venteira',
#   'name': 'Quarto/Final UEFA CUP Lisboa'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 2,
#   'minimum_nights': 1,
#   'coordinates': [38.75894252695615, -9.193017167119498],
#   'room_type': 'Private room',
#   'number_of_reviews': 0,
#   'column_10': 800,
#   'neighbourhood': 'Carnide',
#   'host_id': 15830223,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3115589,
#   'column_20': 'Portugal, Lisbon, Carnide',
#   'name': 'Room for Champions League'},
#  {'updated_date': '2019-04-22',
#   'city': 'Lisbon',
#   'calculated_host_listings_count': 1,
#   'minimum_nights': 1,
#   'coordinates': [38.746816666725785, -9.213504769043555],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 0,
#   'column_10': 1000,
#   'neighbourhood': 'guas Livres',
#   'host_id': 15871370,
#   'column_19': 'Portugal',
#   'availability_365': 0,
#   'id': 3124693,
#   'column_20': 'Portugal, Lisbon, guas Livres',
#   'name': "Lisbon -Champions Final 10''Stadium"},
#  {'updated_date': '2019-04-22',
#   'reviews_per_month': 0.72,
#   'calculated_host_listings_count': 1,
#   'city': 'Lisbon',
#   'minimum_nights': 2,
#   'coordinates': [38.82631965777253, -9.275936216712273],
#   'room_type': 'Entire home/apt',
#   'number_of_reviews': 17,
#   'column_10': 320,
#   'neighbourhood': 'Almargem do Bispo, Pro Pinheiro e Montelavar',
#   'last_review': '2018-10-07',
#   'host_id': 15916831,
#   'column_19': 'Portugal',
#   'availability_365': 22,
#   'id': 3134497,
#   'column_20': 'Portugal, Lisbon, Almargem do Bispo, Pro Pinheiro e Montelavar',
#   'name': 'Villa cerrado das fontainhas'}]

# %%
results_df = pd.DataFrame(results)
results_df.head()
# Out:
#    availability_365  calculated_host_listings_count    city  column_10  \
# 0               292                               7  Lisbon        125
# 1                 0                               1  Lisbon        500
# 2                 0                               1  Lisbon        650
# 3                 0                               1  Lisbon        500
# 4               277                               3  Lisbon         37
#
#   column_19                                          column_20  \
# 0  Portugal                   Portugal, Lisbon, Avenidas Novas
# 1  Portugal                         Portugal, Lisbon, Alcntara
# 2  Portugal           Portugal, Lisbon, So Domingos de Benfica
# 3  Portugal  Portugal, Lisbon, Algs, Linda-a-Velha e Cruz Q...
# 4  Portugal                      Portugal, Lisbon, Misericrdia
#
#                                coordinates   host_id       id last_review  \
# 0  [38.74584282796673, -9.152359763007405]  15282851  2998105  2019-04-17
# 1  [38.70213919994125, -9.177363170810427]  15307946  3003712         NaN
# 2  [38.74499852902329, -9.168202490560926]  15330291  3008031         NaN
# 3  [38.70144477298908, -9.240587547103432]  15415294  3025693         NaN
# 4  [38.71109888002856, -9.148347820132365]  15580486  3063405  2019-04-19
#
#    minimum_nights                                 name  \
# 0               2          Exciting Lisbon Entrecampos
# 1               1  Fantastic Apartment with deck 120m2
# 2               1           Champions League apartment
# 3               1                      Quarto em Algés
# 4               2  Camões Lounge Apartment w/Courtyard
#
#                                  neighbourhood  number_of_reviews  \
# 0                               Avenidas Novas                297
# 1                                     Alcntara                  0
# 2                       So Domingos de Benfica                  0
# 3  Algs, Linda-a-Velha e Cruz Quebrada-Dafundo                  0
# 4                                  Misericrdia                299
#
#    reviews_per_month        room_type updated_date
# 0               4.97  Entire home/apt   2019-04-22
# 1                NaN     Private room   2019-04-22
# 2                NaN  Entire home/apt   2019-04-22
# 3                NaN     Private room   2019-04-22
# 4               5.02  Entire home/apt   2019-04-22

# %%
cleanData = results_df[[ 'column_10','id', 'coordinates', 'room_type', "city", 'column_19']]
cleanData.head()
# Out:
#    column_10       id                              coordinates  \
# 0        125  2998105  [38.74584282796673, -9.152359763007405]
# 1        500  3003712  [38.70213919994125, -9.177363170810427]
# 2        650  3008031  [38.74499852902329, -9.168202490560926]
# 3        500  3025693  [38.70144477298908, -9.240587547103432]
# 4         37  3063405  [38.71109888002856, -9.148347820132365]
#
#          room_type    city column_19
# 0  Entire home/apt  Lisbon  Portugal
# 1     Private room  Lisbon  Portugal
# 2  Entire home/apt  Lisbon  Portugal
# 3     Private room  Lisbon  Portugal
# 4  Entire home/apt  Lisbon  Portugal

# %%
cleanData = cleanData.rename(index=str, columns={"column_10":"Price",
                                                 "id":"Room_Id", 
                                                 "coordinates":"Coordinates",
                                                 "column_19":"Country", 
                                                 "room_type":"Room_Type",
                                                 "city":"City"})

cleanData.head()
# Out:
#    Price  Room_Id                              Coordinates        Room_Type  \
# 0    125  2998105  [38.74584282796673, -9.152359763007405]  Entire home/apt
# 1    500  3003712  [38.70213919994125, -9.177363170810427]     Private room
# 2    650  3008031  [38.74499852902329, -9.168202490560926]  Entire home/apt
# 3    500  3025693  [38.70144477298908, -9.240587547103432]     Private room
# 4     37  3063405  [38.71109888002856, -9.148347820132365]  Entire home/apt
#
#      City   Country
# 0  Lisbon  Portugal
# 1  Lisbon  Portugal
# 2  Lisbon  Portugal
# 3  Lisbon  Portugal
# 4  Lisbon  Portugal

# %%
# Create two lists for the loop results to be placed
lat = []
lon = []

# For each row in a varible,
for row in cleanData['Coordinates']:
   # Try to,
   try:
       # Split the row by comma and append
       # everything before the comma to lat
       lat.append(row[0])
       # Split the row by comma and append
       # everything after the comma to lon
       lon.append(row[1])
   # But if you get an error
   except:
       # append a missing value to lat
       lat.append(np.NaN)
       # append a missing value to lon
       lon.append(np.NaN)

# Create two new columns from lat and lon
cleanData['Latitude'] = lat
cleanData['Longitude'] = lon

# %%
cleanData.drop(columns=["Coordinates"])
cleanData.head()
# Out:
#    Price  Room_Id                              Coordinates        Room_Type  \
# 0    125  2998105  [38.74584282796673, -9.152359763007405]  Entire home/apt
# 1    500  3003712  [38.70213919994125, -9.177363170810427]     Private room
# 2    650  3008031  [38.74499852902329, -9.168202490560926]  Entire home/apt
# 3    500  3025693  [38.70144477298908, -9.240587547103432]     Private room
# 4     37  3063405  [38.71109888002856, -9.148347820132365]  Entire home/apt
#
#      City   Country   Latitude  Longitude
# 0  Lisbon  Portugal  38.745843  -9.152360
# 1  Lisbon  Portugal  38.702139  -9.177363
# 2  Lisbon  Portugal  38.744999  -9.168202
# 3  Lisbon  Portugal  38.701445  -9.240588
# 4  Lisbon  Portugal  38.711099  -9.148348

# %%
cleanData["Selection"] = cleanData["City"]+", "+cleanData["Country"]
cleanData.head(5)
# Out:
#    Price  Room_Id                              Coordinates        Room_Type  \
# 0    125  2998105  [38.74584282796673, -9.152359763007405]  Entire home/apt
# 1    500  3003712  [38.70213919994125, -9.177363170810427]     Private room
# 2    650  3008031  [38.74499852902329, -9.168202490560926]  Entire home/apt
# 3    500  3025693  [38.70144477298908, -9.240587547103432]     Private room
# 4     37  3063405  [38.71109888002856, -9.148347820132365]  Entire home/apt
#
#      City   Country   Latitude  Longitude         Selection
# 0  Lisbon  Portugal  38.745843  -9.152360  Lisbon, Portugal
# 1  Lisbon  Portugal  38.702139  -9.177363  Lisbon, Portugal
# 2  Lisbon  Portugal  38.744999  -9.168202  Lisbon, Portugal
# 3  Lisbon  Portugal  38.701445  -9.240588  Lisbon, Portugal
# 4  Lisbon  Portugal  38.711099  -9.148348  Lisbon, Portugal

# %%
# conn_str = "root:***password***@localhost/airbnb_data"
# engine = create_engine(f'mysql://{conn_str}')

# #check for tables in database
# #engine.table_names()

# #enter data into database
# ***df***.to_sql(name="airbnb_data_tbl", con=engine, if_exists="append",index=False)

# %% [markdown]
# ## working code below

# %%
# # OpenCageGeocode API call to get long lat of city name
# API_key = "30c5a732512c41af8f052a21f806fcce"
# geocoder = OpenCageGeocode(API_key)

# rooms_lat = []   # create empty lists
# rooms_long = []
# cities_lat = [] 
# cities_long = []
# calculated_distance = []

# for index, row in cleanData.iterrows():
#     room_lat1 = row['Latitude']
#     room_long1 = row['Longitude']
    
#     results = geocoder.geocode(row['Selection'])
#     city_lat2 = results[0]['geometry']['lat']
#     city_long2 = results[0]['geometry']['lng']
    
#     def distance(room_long1, room_lat1, city_long2, city_lat2):
#         room_long1, room_lat1, city_long2, city_lat2 = map(radians, [room_long1, room_lat1, city_long2, city_lat2])
#         dlon = city_long2 - room_long1
#         dlat = city_lat2 - room_lat1
#         a = sin(dlat / 2) ** 2 + cos(room_lat1) * cos(city_lat2) * sin(dlon / 2) ** 2
#         return 2 * 3958.756 * asin(sqrt(a)) #6371 km / 3958.756 for miles

#     room_city_distance = distance(room_long1, room_lat1, city_long2, city_lat2)
    
#     calculated_distance.append(room_city_distance)
#     rooms_lat.append(room_lat)
#     rooms_long.append(room_long)
#     cities_lat.append(city_lat)
#     cities_long.append(city_long)

# %%
# print("rooms_lat:", rooms_lat)
# print("rooms_long:", rooms_long)
# print("cities_lat:", cities_lat)
# print("cities_long:", cities_long)
# print("calculated_distance:", calculated_distance)
# Out:
# rooms_lat: [38.82631965777253, 38.82631965777253, 38.82631965777253, 38.82631965777253, 38.82631965777253, 38.82631965777253, 38.82631965777253, 38.82631965777253, 38.82631965777253, 38.82631965777253]
# rooms_long: [-9.275936216712273, -9.275936216712273, -9.275936216712273, -9.275936216712273, -9.275936216712273, -9.275936216712273, -9.275936216712273, -9.275936216712273, -9.275936216712273, -9.275936216712273]
# cities_lat: [38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507]
# cities_long: [-9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919]
# calculated_distance: [2.765742463881356, 2.232266843753696, 3.086511149076642, 5.624249493790029, 0.674723239773414, 0.2377282597145953, 5.961233692751436, 4.664676111902136, 4.947013361274796, 11.111498539256843]

# %%
# # OpenCageGeocode API call to get long lat of city name
# API_key = "30c5a732512c41af8f052a21f806fcce"
# geocoder = OpenCageGeocode(API_key)

# rooms_lat = []   # create empty lists
# rooms_long = []
# cities_lat = [] 
# cities_long = []

# for index, row in cleanData.iterrows():
#     room_lat = row['Latitude']
#     room_long = row['Longitude']
    
#     results = geocoder.geocode(row['Selection'])
#     city_lat = results[0]['geometry']['lat']
#     city_long = results[0]['geometry']['lng']
    
#     rooms_lat.append(room_lat)
#     rooms_long.append(room_long)
#     cities_lat.append(city_lat)
#     cities_long.append(city_long)

# %%
# #room_id: 19051656 / city: New-orleans, United states
# room_lat1 =  29.952861
# city_lat2 =  29.9499323
# room_long1 =  -90.071311
# city_long2 =  -90.0701156

# def distance(room_long1, room_lat1, city_long2, city_lat2):
#     room_long1, room_lat1, city_long2, city_lat2 = map(radians, [room_long1, room_lat1, city_long2, city_lat2])
#     dlon = city_long2 - room_long1
#     dlat = city_lat2 - room_lat1
#     a = sin(dlat / 2) ** 2 + cos(room_lat1) * cos(city_lat2) * sin(dlon / 2) ** 2
#     return 2 * 3958.756 * asin(sqrt(a)) #6371 km / 3958.756 for miles

# %%
# print(distance(room_long1, room_lat1, city_long2, city_lat2))
# Out:
# 0.2146353780659043

# %%
print("rooms_lat:", rooms_lat)
print("rooms_long:", rooms_long)
print("cities_lat:", cities_lat)
print("cities_long:", cities_long)
# Out:
# rooms_lat: [38.74584282796673, 38.70213919994125, 38.74499852902329, 38.70144477298908, 38.71109888002856, 38.70824853381608, 38.751007598903335, 38.75894252695615, 38.746816666725785, 38.82631965777253]
# rooms_long: [-9.152359763007405, -9.177363170810427, -9.168202490560926, -9.240587547103432, -9.148347820132365, -9.140954694999623, -9.232284530702461, -9.193017167119498, -9.213504769043555, -9.275936216712273]
# cities_lat: [38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507, 38.7077507]
# cities_long: [-9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919, -9.1365919]

# %%
# rooms_lat = []   # create empty lists
# rooms_long = []

# #Loops through each room long/lat and pushes to list
# for index, row in cleanData.iterrows():
#     room_lat = row['Latitude']
#     room_long = row['Longitude']

#     rooms_lat.append(room_lat)
#     rooms_long.append(room_long)
    
# # print(rooms_lat)
# # print(rooms_long)

# %%
# API_key = "30c5a732512c41af8f052a21f806fcce"

# geocoder = OpenCageGeocode(API_key)

# city_country = 'New-orleans, United states'

# results = geocoder.geocode(city_country)

# print (results)

# %%
# lat = results[0]['geometry']['lat']
# lng = results[0]['geometry']['lng']
# print (lat, lng)

# %%
# API_key = "30c5a732512c41af8f052a21f806fcce"

# geocoder = OpenCageGeocode(API_key)

# city_country = 'New-orleans, United states'

# results = geocoder.geocode(city_country)

# # print (results)

# %%
# API_key = "30c5a732512c41af8f052a21f806fcce"
# geocoder = OpenCageGeocode(API_key)

# cities_lat = []   # create empty lists
# cities_long = []

# for index, row in cleanData.iterrows():
# #     print(row['Selection'])
    
#     results = geocoder.geocode(row['Selection'])
#     city_lat = results[0]['geometry']['lat']
#     city_long = results[0]['geometry']['lng']
    
#     cities_lat.append(city_lat)
#     cities_long.append(city_long)
    
# # print(cities_lat)
# # print(cities_long)

# %% [markdown]
# ## Lat/Long Distance Calculation

# %%
# this site confirmed the calculation is correct:
# https://www.gpsvisualizer.com/calculators
