# %%
import requests
import json
from pprint import pprint
import numpy as np
import pandas as pd
import os
import datetime as dt

import sqlalchemy
from sqlalchemy import create_engine, func, inspect
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float, Date

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session


from flask import Flask, jsonify

# %%
results = requests.get('https://public.opendatasoft.com/api/records/1.0/download/?dataset=air-bnb-listings&rows=1000&format=json').json()

# %%
pprint(results.fields)
# Out:
# 0      {'updated_date': '2019-05-05', 'reviews_per_mo...
# 1      {'updated_date': '2019-05-05', 'reviews_per_mo...
# 2      {'updated_date': '2019-05-05', 'reviews_per_mo...
# 3      {'updated_date': '2019-05-05', 'reviews_per_mo...
# 4      {'updated_date': '2019-05-05', 'reviews_per_mo...
# 5      {'updated_date': '2019-05-05', 'reviews_per_mo...
# 6      {'updated_date': '2019-05-05', 'reviews_per_mo...
# 7      {'updated_date': '2019-05-05', 'reviews_per_mo...
# 8      {'updated_date': '2019-05-05', 'reviews_per_mo...
# 9      {'updated_date': '2019-05-05', 'reviews_per_mo...
# 10     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 11     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 12     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 13     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 14     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 15     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 16     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 17     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 18     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 19     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 20     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 21     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 22     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 23     {'updated_date': '2019-05-05', 'city': 'New-or...
# 24     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 25     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 26     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 27     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 28     {'updated_date': '2019-05-05', 'reviews_per_mo...
# 29     {'updated_date': '2019-05-05', 'reviews_per_mo...
#                              ...
# 970    {'updated_date': '2019-05-14', 'city': 'Rome',...
# 971    {'updated_date': '2019-05-14', 'city': 'Rome',...
# 972    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 973    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 974    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 975    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 976    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 977    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 978    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 979    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 980    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 981    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 982    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 983    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 984    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 985    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 986    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 987    {'updated_date': '2019-05-14', 'city': 'Rome',...
# 988    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 989    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 990    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 991    {'updated_date': '2019-05-14', 'city': 'Rome',...
# 992    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 993    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 994    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 995    {'updated_date': '2019-05-14', 'city': 'Rome',...
# 996    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 997    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 998    {'updated_date': '2019-05-14', 'reviews_per_mo...
# 999    {'updated_date': '2019-05-14', 'reviews_per_mo...
# Name: fields, Length: 1000, dtype: object

# %%
results_df = pd.read_json(results["fields"].to_json())
results_df.head()
# Out:
#                                           0              1              2    \
# availability_365                          347            302            206
# calculated_host_listings_count             74              1              1
# city                              New-orleans    New-orleans    New-orleans
# column_10                                1003             74            175
# column_19                       United states  United states  United states
#
#                                           3              4              5    \
# availability_365                            0             25            335
# calculated_host_listings_count              2              4             17
# city                              New-orleans    New-orleans    New-orleans
# column_10                                  86             84            296
# column_19                       United states  United states  United states
#
#                                           6              7              8    \
# availability_365                          146              0             42
# calculated_host_listings_count              1              1              3
# city                              New-orleans    New-orleans    New-orleans
# column_10                                  73            130            250
# column_19                       United states  United states  United states
#
#                                           9    ...      990    991    992  \
# availability_365                          244  ...      356    365    360
# calculated_host_listings_count              1  ...        1      4     10
# city                              New-orleans  ...     Rome   Rome   Rome
# column_10                                 200  ...       39     89    350
# column_19                       United states  ...    Italy  Italy  Italy
#
#                                   993    994    995    996    997    998  \
# availability_365                  315    314      0    281    249    338
# calculated_host_listings_count      3      1      5      2      1      2
# city                             Rome   Rome   Rome   Rome   Rome   Rome
# column_10                          20     48     75    119     60     79
# column_19                       Italy  Italy  Italy  Italy  Italy  Italy
#
#                                   999
# availability_365                   75
# calculated_host_listings_count      3
# city                             Rome
# column_10                          25
# column_19                       Italy
#
# [5 rows x 1000 columns]

# %%
transpose = results_df.transpose()
transpose.head()
# Out:
#   availability_365 calculated_host_listings_count         city column_10  \
# 0              347                             74  New-orleans      1003
# 1              302                              1  New-orleans        74
# 2              206                              1  New-orleans       175
# 3                0                              2  New-orleans        86
# 4               25                              4  New-orleans        84
#
#        column_19                                          column_20  \
# 0  United states  United states, New-orleans, Central Business D...
# 1  United states  United states, New-orleans, Viavant - Venetian...
# 2  United states  United states, New-orleans, Marlyville - Fonta...
# 3  United states  United states, New-orleans, Lower Garden District
# 4  United states           United states, New-orleans, Seventh Ward
#
#                        coordinates    host_id        id last_review  \
# 0  [29.9528609234, -90.0713113928]  114353388  19051656  2017-10-19
# 1  [29.9870343373, -89.9449684809]   61310992  19079967  2019-04-28
# 2   [29.9547710049, -90.119942163]   22171971  19123547  2019-04-22
# 3  [29.9380891716, -90.0735907443]     710534  19245713  2019-04-29
# 4  [29.9718554828, -90.0692218041]    2428040  19267950  2019-04-27
#
#   minimum_nights                                             name  \
# 0              1  Gorgeous Stay Alfred on North Carondelet Street
# 1              1         Cozy New Orleans Efficiency On The Water
# 2              2                   Townhome on the Streetcar Line
# 3              2     Stylish 1BR Shotgun in Lower Garden District
# 4              1                   Relaxing 3BR Balcony Apartment
#
#                neighbourhood number_of_reviews reviews_per_month  \
# 0  Central Business District                 1              0.05
# 1   Viavant - Venetian Isles                20              4.84
# 2  Marlyville - Fontainbleau                74              3.65
# 3      Lower Garden District                89               3.9
# 4               Seventh Ward                22              1.08
#
#          room_type updated_date
# 0  Entire home/apt   2019-05-05
# 1  Entire home/apt   2019-05-05
# 2  Entire home/apt   2019-05-05
# 3  Entire home/apt   2019-05-05
# 4  Entire home/apt   2019-05-05

# %%
cleanData = transpose[[ 'column_10','id', 'coordinates', 'room_type', "city", 'column_19']]
cleanData.head()
# Out:
#   column_10        id                      coordinates        room_type  \
# 0      1003  19051656  [29.9528609234, -90.0713113928]  Entire home/apt
# 1        74  19079967  [29.9870343373, -89.9449684809]  Entire home/apt
# 2       175  19123547   [29.9547710049, -90.119942163]  Entire home/apt
# 3        86  19245713  [29.9380891716, -90.0735907443]  Entire home/apt
# 4        84  19267950  [29.9718554828, -90.0692218041]  Entire home/apt
#
#           city      column_19
# 0  New-orleans  United states
# 1  New-orleans  United states
# 2  New-orleans  United states
# 3  New-orleans  United states
# 4  New-orleans  United states

# %%
cleanData = cleanData.rename(index=str, columns={"column_10":"Price",
                                                 "id":"Room_Id", 
                                                 "coordinates":"Coordinates",
                                                 "column_19":"Country", 
                                                 "room_type":"Room_Type",
                                                 "city":"City"})

cleanData.head()
# Out:
#   Price   Room_Id                      Coordinates        Room_Type  \
# 0  1003  19051656  [29.9528609234, -90.0713113928]  Entire home/apt
# 1    74  19079967  [29.9870343373, -89.9449684809]  Entire home/apt
# 2   175  19123547   [29.9547710049, -90.119942163]  Entire home/apt
# 3    86  19245713  [29.9380891716, -90.0735907443]  Entire home/apt
# 4    84  19267950  [29.9718554828, -90.0692218041]  Entire home/apt
#
#           City        Country
# 0  New-orleans  United states
# 1  New-orleans  United states
# 2  New-orleans  United states
# 3  New-orleans  United states
# 4  New-orleans  United states

# %%
# Create two lists for the loop results to be placed
lat = []
lon = []

# For each row in a varible,
for row in cleanData['Coordinates']:
   # Try to,
   try:
       # Split the row by comma and append
       # everything before the comma to lat
       lat.append(row[0])
       # Split the row by comma and append
       # everything after the comma to lon
       lon.append(row[1])
   # But if you get an error
   except:
       # append a missing value to lat
       lat.append(np.NaN)
       # append a missing value to lon
       lon.append(np.NaN)

# Create two new columns from lat and lon
cleanData['Latitude'] = lat
cleanData['Longitude'] = lon

# %%
cleanData.drop(columns=["Coordinates"])
cleanData.head()
# Out:
#   Price   Room_Id                      Coordinates        Room_Type  \
# 0  1003  19051656  [29.9528609234, -90.0713113928]  Entire home/apt
# 1    74  19079967  [29.9870343373, -89.9449684809]  Entire home/apt
# 2   175  19123547   [29.9547710049, -90.119942163]  Entire home/apt
# 3    86  19245713  [29.9380891716, -90.0735907443]  Entire home/apt
# 4    84  19267950  [29.9718554828, -90.0692218041]  Entire home/apt
#
#           City        Country   Latitude  Longitude
# 0  New-orleans  United states  29.952861 -90.071311
# 1  New-orleans  United states  29.987034 -89.944968
# 2  New-orleans  United states  29.954771 -90.119942
# 3  New-orleans  United states  29.938089 -90.073591
# 4  New-orleans  United states  29.971855 -90.069222

# %%
cleanData["Selection"] = cleanData["City"]+", "+cleanData["Country"]
cleanData.head()
# Out:
#   Price   Room_Id                      Coordinates        Room_Type  \
# 0  1003  19051656  [29.9528609234, -90.0713113928]  Entire home/apt
# 1    74  19079967  [29.9870343373, -89.9449684809]  Entire home/apt
# 2   175  19123547   [29.9547710049, -90.119942163]  Entire home/apt
# 3    86  19245713  [29.9380891716, -90.0735907443]  Entire home/apt
# 4    84  19267950  [29.9718554828, -90.0692218041]  Entire home/apt
#
#           City        Country   Latitude  Longitude  \
# 0  New-orleans  United states  29.952861 -90.071311
# 1  New-orleans  United states  29.987034 -89.944968
# 2  New-orleans  United states  29.954771 -90.119942
# 3  New-orleans  United states  29.938089 -90.073591
# 4  New-orleans  United states  29.971855 -90.069222
#
#                     Selection
# 0  New-orleans, United states
# 1  New-orleans, United states
# 2  New-orleans, United states
# 3  New-orleans, United states
# 4  New-orleans, United states

# %%
conn_str = "root:***password***@localhost/airbnb_data"
engine = create_engine(f'mysql://{conn_str}')

#check for tables in database
#engine.table_names()

#enter data into database
***df***.to_sql(name="airbnb_data_tbl", con=engine, if_exists="append",index=False)
